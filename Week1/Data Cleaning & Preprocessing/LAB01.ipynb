# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
import csv

# %%
df = pd.read_csv(r"C:\Users\naser\Sdaia BootCamp\Anaconda\LAB\Datasets\Traffic.csv")

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df.tail()
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 5947  10:45:00 PM     9        Thursday        16          3         1
# 5948  11:00:00 PM     9        Thursday        11          0         1
# 5949  11:15:00 PM     9        Thursday        15          4         1
# 5950  11:30:00 PM     9        Thursday        16          5         0
# 5951  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 5947          36     56            normal
# 5948          30     42            normal
# 5949          25     45            normal
# 5950          27     48            normal
# 5951          15     33               low

# %%
df.sample()
# Out:
#             Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 1810  8:30:00 PM    28        Saturday        74         20        17
#
#       TruckCount  Total Traffic Situation
# 1810          24    135            normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               5952 non-null   object
#  1   Date               5952 non-null   int64
#  2   Day of the week    5952 non-null   object
#  3   CarCount           5952 non-null   int64
#  4   BikeCount          5952 non-null   int64
#  5   BusCount           5952 non-null   int64
#  6   TruckCount         5952 non-null   int64
#  7   Total              5952 non-null   int64
#  8   Traffic Situation  5952 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 418.6+ KB

# %%
df.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  5952.000000  5952.000000  5952.000000  5952.000000  5952.000000
# mean     16.000000    65.440692    12.161458    12.912970    18.646337
# std       8.945023    44.749335    11.537944    12.497736    10.973139
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.750000     3.000000     2.000000    10.000000
# 50%      16.000000    62.000000     9.000000    10.000000    18.000000
# 75%      24.000000   103.000000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total
# count  5952.000000
# mean    109.161458
# std      55.996312
# min      21.000000
# 25%      54.000000
# 50%     104.000000
# 75%     153.000000
# max     279.000000

# %%
df.shape
# Out:
# (5952, 9)

# %%
df["Day of the week"].value_counts()
# Out:
# Tuesday      960
# Wednesday    960
# Thursday     960
# Friday       768
# Saturday     768
# Sunday       768
# Monday       768
# Name: Day of the week, dtype: int64

# %%
df.isna().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df["Traffic Situation"]
# Out:
# 0       normal
# 1       normal
# 2       normal
# 3       normal
# 4       normal
#          ...
# 5947    normal
# 5948    normal
# 5949    normal
# 5950    normal
# 5951       low
# Name: Traffic Situation, Length: 5952, dtype: object

# %%
df.iloc[86:89]
# Out:
#            Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 86   9:30:00 PM    10         Tuesday        96          0        19
# 87   9:45:00 PM    10         Tuesday        14          1         0
# 88  10:00:00 PM    10         Tuesday         7          1         0
#
#     TruckCount  Total Traffic Situation
# 86          23    138            normal
# 87          27     42            normal
# 88          36     44            normal

# %%
df.loc[86:89]
# Out:
#            Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 86   9:30:00 PM    10         Tuesday        96          0        19
# 87   9:45:00 PM    10         Tuesday        14          1         0
# 88  10:00:00 PM    10         Tuesday         7          1         0
# 89  10:15:00 PM    10         Tuesday         9          0         2
#
#     TruckCount  Total Traffic Situation
# 86          23    138            normal
# 87          27     42            normal
# 88          36     44            normal
# 89          35     46            normal

# %%
df.iloc[5]
# Out:
# Time                 1:15:00 AM
# Date                         10
# Day of the week         Tuesday
# CarCount                     15
# BikeCount                     1
# BusCount                      1
# TruckCount                   39
# Total                        56
# Traffic Situation        normal
# Name: 5, dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # selection_indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\naser\Sdaia BootCamp\Anaconda\LAB\Datasets\Traffic.csv")

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
df['Day of the week']
# Out:
# 0        Tuesday
# 1        Tuesday
# 2        Tuesday
# 3        Tuesday
# 4        Tuesday
#           ...
# 5947    Thursday
# 5948    Thursday
# 5949    Thursday
# 5950    Thursday
# 5951    Thursday
# Name: Day of the week, Length: 5952, dtype: object

# %%
df[['Time', 'Date','Day of the week']]
# Out:
#              Time  Date Day of the week
# 0     12:00:00 AM    10         Tuesday
# 1     12:15:00 AM    10         Tuesday
# 2     12:30:00 AM    10         Tuesday
# 3     12:45:00 AM    10         Tuesday
# 4      1:00:00 AM    10         Tuesday
# ...           ...   ...             ...
# 5947  10:45:00 PM     9        Thursday
# 5948  11:00:00 PM     9        Thursday
# 5949  11:15:00 PM     9        Thursday
# 5950  11:30:00 PM     9        Thursday
# 5951  11:45:00 PM     9        Thursday
#
# [5952 rows x 3 columns]

# %%
df.iloc[5]
# Out:
# Time                 1:15:00 AM
# Date                         10
# Day of the week         Tuesday
# CarCount                     15
# BikeCount                     1
# BusCount                      1
# TruckCount                   39
# Total                        56
# Traffic Situation        normal
# Name: 5, dtype: object

# %%
df.iloc[5:10]
# Out:
#          Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 5  1:15:00 AM    10         Tuesday        15          1         1
# 6  1:30:00 AM    10         Tuesday        14          2         2
# 7  1:45:00 AM    10         Tuesday        13          2         1
# 8  2:00:00 AM    10         Tuesday         7          0         0
# 9  2:15:00 AM    10         Tuesday        13          0         0
#
#    TruckCount  Total Traffic Situation
# 5          39     56            normal
# 6          27     45            normal
# 7          20     36            normal
# 8          26     33            normal
# 9          34     47            normal

# %%
df.loc[5:10, ['Date', 'Time']]
# Out:
#     Date        Time
# 5     10  1:15:00 AM
# 6     10  1:30:00 AM
# 7     10  1:45:00 AM
# 8     10  2:00:00 AM
# 9     10  2:15:00 AM
# 10    10  2:30:00 AM

# %%
df = df.set_index(['Day of the week', 'Time'])
df.loc[('Monday', '12:00:00 AM')]
# Out:
# C:\Users\naser\AppData\Local\Temp\ipykernel_14720\2670919417.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[('Monday', '12:00:00 AM')]
#                              Date  CarCount  BikeCount  BusCount  TruckCount  \
# Day of the week Time
# Monday          12:00:00 AM    16        11          2         2          39
#                 12:00:00 AM    23        15          1         0          37
#                 12:00:00 AM    30        14          2         0          33
#                 12:00:00 AM     6         9          2         0          27
#                 12:00:00 AM    16        18          4         1          28
#                 12:00:00 AM    23        13          2         1          17
#                 12:00:00 AM    30        13          3         1          12
#                 12:00:00 AM     6        11          3         0          26
#
#                              Total Traffic Situation
# Day of the week Time
# ...

# %%
df = df.reset_index()

# %%
df[df['Total'] > 250]
# Out:
#      Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 3303          Friday   9:45:00 AM    13       171         59        27
# 3307          Friday  10:45:00 AM    13       178         68        28
# 3308          Friday  11:00:00 AM    13       169         70        20
# 3311          Friday  11:45:00 AM    13       179         46        27
# 3315          Friday  12:45:00 PM    13       174         67        30
# 3318          Friday   1:30:00 PM    13       175         63        19
# 3319          Friday   1:45:00 PM    13       172         62        20
# 3321          Friday   2:15:00 PM    13       172         65        18
# 3974          Friday   9:30:00 AM    20       170         62        18
# 3976          Friday  10:00:00 AM    20       166         63        22
# 3986          Friday  12:30:00 PM    20       173         63        13
# 3991          Friday   1:45:00 PM    20       168         59        24
# ...

# %%
df.query('Total > 250')
# Out:
#      Day of the week         Time  Date  CarCount  BikeCount  BusCount  \
# 3303          Friday   9:45:00 AM    13       171         59        27
# 3307          Friday  10:45:00 AM    13       178         68        28
# 3308          Friday  11:00:00 AM    13       169         70        20
# 3311          Friday  11:45:00 AM    13       179         46        27
# 3315          Friday  12:45:00 PM    13       174         67        30
# 3318          Friday   1:30:00 PM    13       175         63        19
# 3319          Friday   1:45:00 PM    13       172         62        20
# 3321          Friday   2:15:00 PM    13       172         65        18
# 3974          Friday   9:30:00 AM    20       170         62        18
# 3976          Friday  10:00:00 AM    20       166         63        22
# 3986          Friday  12:30:00 PM    20       173         63        13
# 3991          Friday   1:45:00 PM    20       168         59        24
# ...

# %% [markdown]
# # Grouping Aggregation

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\naser\Sdaia BootCamp\Anaconda\LAB\Datasets\Traffic.csv")

# %%
df.head()
# Out:
#           Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0  12:00:00 AM    10         Tuesday        13          2         2
# 1  12:15:00 AM    10         Tuesday        14          1         1
# 2  12:30:00 AM    10         Tuesday        10          2         2
# 3  12:45:00 AM    10         Tuesday        10          2         2
# 4   1:00:00 AM    10         Tuesday        11          2         1
#
#    TruckCount  Total Traffic Situation
# 0          24     41            normal
# 1          36     52            normal
# 2          32     46            normal
# 3          36     50            normal
# 4          34     48            normal

# %%
grouped_data = df.groupby(['Day of the week'])['Total'].sum()
print(grouped_data)
# Out:
# Day of the week
# Friday        81626
# Monday        83576
# Saturday      84542
# Sunday        84201
# Thursday     105074
# Tuesday      104882
# Wednesday    105828
# Name: Total, dtype: int64

# %%
grouped_data = df.groupby(['Day of the week', 'Date'])['Total'].sum()
print(grouped_data)
# Out:
# Day of the week  Date
# Friday           3       20198
#                  13      20315
#                  20      20608
#                  27      20505
# Monday           6       21238
#                  16      20800
#                  23      20555
#                  30      20983
# Saturday         4       21187
#                  14      20772
#                  21      10135
#                  22      11515
#                  28      20933
# Sunday           5       21398
#                  15      21157
#                  21      10844
#                  22       9912
#                  29      20890
# Thursday         2       20890
#                  9       21236
#                  12      20999
#                  19      20727
#                  26      21222
# Tuesday          7       21010
#                  10      21744
#                  17      20218
#                  24      20704
#                  31      21206
# Wednesday        1       21159
# ...

# %% [markdown]
# # Multiiple Grouping

# %% [markdown]
# Aggregation

# %%
df.describe()
# Out:
#               Date     CarCount    BikeCount     BusCount   TruckCount  \
# count  5952.000000  5952.000000  5952.000000  5952.000000  5952.000000
# mean     16.000000    65.440692    12.161458    12.912970    18.646337
# std       8.945023    44.749335    11.537944    12.497736    10.973139
# min       1.000000     5.000000     0.000000     0.000000     0.000000
# 25%       8.000000    18.750000     3.000000     2.000000    10.000000
# 50%      16.000000    62.000000     9.000000    10.000000    18.000000
# 75%      24.000000   103.000000    19.000000    20.000000    27.000000
# max      31.000000   180.000000    70.000000    50.000000    60.000000
#
#              Total
# count  5952.000000
# mean    109.161458
# std      55.996312
# min      21.000000
# 25%      54.000000
# 50%     104.000000
# 75%     153.000000
# max     279.000000

# %%
df['CarCount'].sum()
# Out:
# 389503

# %%
df['BikeCount'].mean()
# Out:
# 12.161458333333334

# %%
df['BusCount'].max()
# Out:
# 50

# %%
df['TruckCount'].min()
# Out:
# 0

# %%
df['Day of the week'].count()
# Out:
# 5952

# %%
grouped_data = df.groupby(['Day of the week']).agg(
    Total_Cars = ('CarCount', 'sum'),
    Average_Cars = ('CarCount', 'mean'),
    Maximum_Cars = ('CarCount', 'max'),
    Minimum_Cars = ('CarCount', 'min'),
    Count = ('CarCount', 'count')
    
)
grouped_data
# Out:
#                  Total_Cars  Average_Cars  Maximum_Cars  Minimum_Cars  Count
# Day of the week
# Friday                49890     64.960938           180             5    768
# Monday                49724     64.744792           150             5    768
# Saturday              50457     65.699219           150             5    768
# Sunday                50183     65.342448           150             5    768
# Thursday              62779     65.394792           150             5    960
# Tuesday               63014     65.639583           150             5    960
# Wednesday             63456     66.100000           150             5    960

# %%
grouped_data = df.groupby(['Day of the week', 'Traffic Situation']).agg(
    Total_Cars = ('CarCount', 'sum'),
    Average_Cars = ('CarCount', 'mean'),
    Maximum_Cars = ('CarCount', 'max'),
    Minimum_Cars = ('CarCount', 'min'),
    Count = ('CarCount', 'count')
    
)
grouped_data
# Out:
#                                    Total_Cars  Average_Cars  Maximum_Cars  \
# Day of the week Traffic Situation
# Friday          heavy                   24024    145.600000           180
#                 high                     2203     66.757576            79
#                 low                     10428     46.346667            90
#                 normal                  13235     38.362319           128
# Monday          heavy                   18541    127.868966           150
#                 high                     3892     79.428571           113
#                 low                      4144     44.085106            94
#                 normal                  23147     48.222917           126
# Saturday        heavy                   19276    128.506667           150
#                 high                     2861     77.324324           108
#                 low                      3929     41.797872           118
# ...

# %% [markdown]
# # Merge

# %%
import pandas as pd
import numpy as np

# Create dataframes for examples
left_dataframe = pd.DataFrame({"ID": [1,2,3,4], "left_side": "LEFT"})
right_dataframe = pd.DataFrame({"ID": [3,4,5,6], "right_side": "RIGHT"})

# %%
# Left merge on "ID" column 
pd.merge(left=left_dataframe, right=right_dataframe, on="ID", how="left")
# Out:
#    ID left_side right_side
# 0   1      LEFT        NaN
# 1   2      LEFT        NaN
# 2   3      LEFT      RIGHT
# 3   4      LEFT      RIGHT

# %%
# Code for a right merge
pd.merge(left=left_dataframe, right=right_dataframe, on="ID", how="right")
# Out:
#    ID left_side right_side
# 0   3      LEFT      RIGHT
# 1   4      LEFT      RIGHT
# 2   5       NaN      RIGHT
# 3   6       NaN      RIGHT

# %%
# Inner merge on ID column
pd.merge(left=left_dataframe, right=right_dataframe, on="ID", how="inner")
# Out:
#    ID left_side right_side
# 0   3      LEFT      RIGHT
# 1   4      LEFT      RIGHT

# %%
# Outer merge on ID column
pd.merge(left=left_dataframe, right=right_dataframe, on="ID", how="outer")
# Out:
#    ID left_side right_side
# 0   1      LEFT        NaN
# 1   2      LEFT        NaN
# 2   3      LEFT      RIGHT
# 3   4      LEFT      RIGHT
# 4   5       NaN      RIGHT
# 5   6       NaN      RIGHT

# %%
# Load restaurant ratings and parking data into dataframes
ratings = pd.read_csv(r"C:\Users\naser\Sdaia BootCamp\Anaconda\LAB\Datasets\rating_final.csv")
parking = pd.read_csv(r"C:\Users\naser\Sdaia BootCamp\Anaconda\LAB\Datasets\chefmozparking.csv")

# Left merge: Keep everything from the left, drop things from the right (if they don't match)
left_merge = pd.merge(left=ratings, right=parking, on="placeID", how="left")
left_merge.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating parking_lot
# 0  U1077   135085       2            2               2      public
# 1  U1077   135038       2            2               1        none
# 2  U1077   132825       2            2               2        none
# 3  U1077   135060       1            2               2        none
# 4  U1068   135104       1            1               2         yes
