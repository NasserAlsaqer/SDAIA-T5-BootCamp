# %% [markdown]
# # Time Series Forecasting Practice Exercise
#
# In this practice exercise, you will work on a time series forecasting task. The goal is to go through the entire workflow from loading the data to evaluating the model and making predictions. Follow each step carefully. The dataset is stored in the `Datasets` file with the name `Aquifer_Petrignano` the target is to predict `Depth_to_Groundwater_P24` column.
#
# ## Dataset: Aquifer Petrignano
#
# ### Dataset Overview:
#
# - **Name**: Aquifer Petrignano
# - **Description**: This dataset contains time series data related to groundwater levels, rainfall, temperature, and hydrometry in the Aquifer Petrignano region. The data is collected over multiple years, capturing various environmental measurements. It is particularly useful for modeling groundwater levels, climate analysis, and time series forecasting.
# - **Time Period**: Starting from 14/03/2006
# - **Frequency**: Daily observations
#
# ### Features:
#
# 1. **Date**: The date of the observation in `DD/MM/YYYY` format.
# 2. **Rainfall_Bastia_Umbra**: Daily rainfall measurement in the Bastia Umbra region (mm).
# 3. **Depth_to_Groundwater_P24**: Depth to groundwater at observation point P24 (meters).
# 4. **Depth_to_Groundwater_P25**: Depth to groundwater at observation point P25 (meters).
# 5. **Temperature_Bastia_Umbra**: Daily temperature in the Bastia Umbra region (°C).
# 6. **Temperature_Petrignano**: Daily temperature in the Petrignano region (°C).
# 7. **Volume_C10_Petrignano**: Water volume measured at station C10 in Petrignano (m³).
# 8. **Hydrometry_Fiume_Chiascio_Petrignano**: Hydrometry measurements of the Fiume Chiascio river in Petrignano (m).

# %% [markdown]
# ## Load the Data
#
# Load the time series dataset into a pandas DataFrame.
#
# **Instructions:**
# - Use `pandas` to load your dataset.
# - Display the first few rows to understand its structure.
# - Make sure the datetime column is correctly parsed.

# %%
import pandas as pd

df = pd.read_csv('Datasets/Aquifer_Petrignano.csv',parse_dates=['Date'])

df.head()

# df.info()

# df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/c1/9m9gfrj553l8956nyk7q8gw40000gn/T/ipykernel_19526/1797517071.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('Datasets/Aquifer_Petrignano.csv',parse_dates=['Date'])
#         Date  Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# 0 2009-07-28                    0.0                    -28.90
# 1 2015-06-21                    0.0                    -20.79
# 2 2019-10-10                    0.0                    -27.36
# 3 2011-12-09                    0.0                    -27.78
# 4 2011-09-20                    1.0                    -26.09
#
#    Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  Temperature_Petrignano  \
# 0                    -28.12                      27.4                    25.6
# 1                    -20.45                      20.8                     0.0
# 2                    -26.75                      20.3                    20.0
# 3                    -26.98                       9.2                     8.8
# 4                    -25.55                      15.7                    15.7
#
#    Volume_C10_Petrignano  Hydrometry_Fiume_Chiascio_Petrignano
# 0             -34833.888                                   1.9
# 1             -18681.408                                   0.0
# 2             -28288.224                                   2.3
# 3             -37215.072                                   2.0
# 4             -30856.896                                   2.0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Perform exploratory data analysis on the dataset.
#
# **Instructions:**
# - Plot the time series data.
# - Analyze trends, seasonality, and potential outliers.
# - Plot boxplots or scatter plots to identify any outliers or anomalies in the data.
# - Seasonal Decomposition: Use seasonal_decompose from the statsmodels library to break down the time series data into trend, seasonality, and residual components. Analyze each component to gain insights into the long-term movement (trend), regular patterns (seasonality), and remaining fluctuations (residuals).
#
# Do more if needed!

# %%
df = df.sort_values(by='Date')
ts_df = df.set_index('Date')

# %%
ts_df.isna().sum()
# Out:
# Rainfall_Bastia_Umbra                   1024
# Depth_to_Groundwater_P24                  55
# Depth_to_Groundwater_P25                  39
# Temperature_Bastia_Umbra                1024
# Temperature_Petrignano                  1024
# Volume_C10_Petrignano                    198
# Hydrometry_Fiume_Chiascio_Petrignano    1024
# dtype: int64

# %%
ts_df.dropna(inplace=True)

# %%
ts_df = ts_df.resample('M').mean()

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(15,10))
plt.plot(ts_df.index,ts_df['Depth_to_Groundwater_P24'], marker='.')
plt.xticks(rotation=45)
plt.grid(True)

# %%
ts_df['Moving_Avg'] = ts_df['Depth_to_Groundwater_P24'].rolling(window=3).mean()
ts_df[['Depth_to_Groundwater_P24', 'Moving_Avg']].plot(figsize=(10, 6))
plt.title('Moving Average')
plt.show()


from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts_df['Depth_to_Groundwater_P24'], model='additive')
decomposition.plot()
plt.show()

# %%
# for i in ts_df.columns:
#     ts_df[i].plot(kind='box')
#     plt.show()
    
# import seaborn as sns
# sns.pairplot(ts_df)

# %%
# ts_df.duplicated().sum()

# %% [markdown]
# ## Data Preprocessing
#
# Clean and preprocess the data.
#
# **Instructions:**
# - Handle any missing values in the dataset.
# - If necessary, resample the data to ensure consistent time intervals.
# - Create any additional features needed, such as lags or moving averages.
# - Make sure that the dates are sorted correctly.
#
# Do more if needed!

# %% [markdown]
# ## Feature Engineering
#
# ### Instructions:
#
# - **Shift Method**: Use the `shift` method to create a new column `Prev_Depth_to_Groundwater_P24`, which represents the previous day's groundwater depth. This helps capture the effect of past values on current observations.
#
# - **Date Features**: Extract meaningful time-based features from the `Date` column to enhance the model's ability to detect temporal patterns. These features include:
#   - **Day of the week**: To capture weekly seasonality.
#   - **Month**: To capture monthly trends.
#   - **Day of the year**: Useful for modeling yearly seasonality.
#   - **IsWeekend**: A binary feature that distinguishes between weekdays and weekends.
#   - **Difference between Depth_to_Groundwater_P24**: Calculate the difference between consecutive values in the `Depth_to_Groundwater_P24` column to highlight short-term changes in groundwater depth.

# %%
lags = []
for i in range(1, 6):
    ts_df[f'Lag_{i}'] = ts_df['Depth_to_Groundwater_P24'].shift(i)
    lags.append(f'Lag_{i}')
    
    
ts_df.dropna(inplace=True)

# %%
ts_df
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2009-06-30               0.010000                -28.167333
# 2009-07-31               0.058065                -28.391613
# 2009-08-31               1.522581                -28.819355
# 2009-09-30               0.453333                -29.108667
# 2009-10-31               0.345161                -29.456129
# ...                           ...                       ...
# 2020-02-29               0.641379                -25.523103
# 2020-03-31               2.492857                -25.170357
# 2020-04-30               1.434483                -25.315517
# 2020-05-31               1.470968                -25.180645
# 2020-06-30               2.268966                -25.271034
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2009-06-30                -27.522000                 21.203333
# 2009-07-31                -27.721613                 25.393548
# 2009-08-31                -28.175806                 25.780645
# 2009-09-30                -28.435000                 21.060000
# 2009-10-31                -28.755161                 13.948387
# ...                              ...                       ...
# 2020-02-29                -25.261724                  8.989655
# 2020-03-31                -24.965000                  9.689286
# 2020-04-30                -24.807586                 14.293103
# 2020-05-31                -24.716774                 18.754839
# 2020-06-30                -24.819655                 21.286207
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2009-06-30               20.273333          -31514.832000
# 2009-07-31               24.287097          -32104.790710
# 2009-08-31               25.122581          -31489.901419
# 2009-09-30               20.723333          -33777.964800
# 2009-10-31               13.754839          -35408.002065
# ...                            ...                    ...
# 2020-02-29                8.748276          -28354.096552
# 2020-03-31                9.403571          -26900.362286
# 2020-04-30               13.796552          -24687.936000
# 2020-05-31               18.235484          -24104.067097
# 2020-06-30               20.662069          -27504.576000
#
#             Hydrometry_Fiume_Chiascio_Petrignano  Moving_Avg      Lag_1  \
# Date
# 2009-06-30                              2.053333  -28.147380 -28.045806
# 2009-07-31                              2.058065  -28.201584 -28.167333
# 2009-08-31                              2.041935  -28.459434 -28.391613
# 2009-09-30                              2.000000  -28.773211 -28.819355
# 2009-10-31                              1.945161  -29.128050 -29.108667
# ...                                          ...         ...        ...
# 2020-02-29                              2.420690  -25.921357 -25.881935
# 2020-03-31                              2.721429  -25.525132 -25.523103
# 2020-04-30                              2.496552  -25.336326 -25.170357
# 2020-05-31                              2.470968  -25.222173 -25.315517
# 2020-06-30                              2.582759  -25.255732 -25.180645
#
#                 Lag_2      Lag_3      Lag_4      Lag_5
# Date
# 2009-06-30 -28.229000 -29.041613 -29.918214 -31.278387
# 2009-07-31 -28.045806 -28.229000 -29.041613 -29.918214
# 2009-08-31 -28.167333 -28.045806 -28.229000 -29.041613
# 2009-09-30 -28.391613 -28.167333 -28.045806 -28.229000
# 2009-10-31 -28.819355 -28.391613 -28.167333 -28.045806
# ...               ...        ...        ...        ...
# 2020-02-29 -26.359032 -26.929667 -27.336452 -26.987000
# 2020-03-31 -25.881935 -26.359032 -26.929667 -27.336452
# 2020-04-30 -25.523103 -25.881935 -26.359032 -26.929667
# 2020-05-31 -25.170357 -25.523103 -25.881935 -26.359032
# 2020-06-30 -25.315517 -25.170357 -25.523103 -25.881935
#
# [133 rows x 13 columns]

# %%
ts_df['Day_of_the_week']= ts_df.index.day_of_week
ts_df['Month'] = ts_df.index.month
ts_df['Day_of_the_year'] = ts_df.index.day_of_year
ts_df['isWeeked']= ts_df['Day_of_the_week'] >= 5


ts_df['Difference_between_depth_to_groundwater_p24']= ts_df['Day_of_the_week'].diff()

# %%
ts_df.isna().sum()
ts_df.dropna(inplace=True)

# %% [markdown]
# ## Train-Test Split
#
# Split the dataset into training and testing sets.
#
# **Instructions:**
# - Ensure the split maintains the time order of the data.
# - Decide on an appropriate ratio for splitting the data.

# %%
from sklearn.model_selection import train_test_split

X = ts_df.drop(columns=['Depth_to_Groundwater_P24'])
y = ts_df['Depth_to_Groundwater_P24']

X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42,test_size=0.2,shuffle=False)

# %% [markdown]
# ## Feature Scaling
#
# Apply feature scaling to the data if needed.
#
# **Instructions:**
# - Use a scaling method such as MinMaxScaler or StandardScaler.
# - Ensure scaling is applied correctly to both training and testing data.

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# ts_df.describe()

mms = MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %% [markdown]
# ## Models Selection
#
# Choose two models for time series forecasting.
#
# **Instructions:**
# - Select two models such as ARIMA, SARIMA, RNN, LSTM, or GRU.
# - Train these models and then compare their performance.

# %% [markdown]
# ### Model 1 Training
#
# Train your first model on the training dataset.
#
# **Instructions:**
# - Fit the first model to the training data.
# - Ensure to monitor the training process.

# %%
# pip install pmdarima

# %%
# ts_df

# %%
# from pmdarima import auto_arima


# stepwise_fit = auto_arima(ts_df['Depth_to_Groundwater_P24'], start_p = 1, start_q = 1,
#                         max_p = 5, max_q = 5, m = 12,
#                         start_P = 1, seasonal = True,
#                         d = None, D = None, trace = True,
#                         # error_action ='ignore',   # we don't want to know if an order does not work
#                         # suppress_warnings = True,  # we don't want convergence warnings
#                         stepwise = True)

# %%
# stepwise_fit.summary()

# %% [markdown]
# ### Make 1 Predictions
#
# Generate predictions on the test dataset.
#
# ### Instructions:
# - Use the trained model to make predictions on the test data.
# - Store the predictions for further analysis.

# %%
# y_pred = stepwise_fit.predict(X_test,typ='levels').rename('Predictions')

# %% [markdown]
# ### Model 1 Evaluation
#
# Evaluate the performance of your first model on the test dataset.
#
# **Instructions:**
# - Calculate evaluation metrics such as MAE, MSE, RMSE, or MAPE.
# - Plot the predicted vs actual values for the test set.
# - Plot the loss and the validation loss.

# %%
# y_pred.plot()
# pd.DataFrame(y_test).plot()

# %%
# from sklearn.metrics import mean_squared_error
# from statsmodels.tools.eval_measures import rmse


# print(mean_squared_error(y_pred,y_test))
# print(rmse(y_pred,y_test))

# %% [markdown]
# mse = 1.29

# %% [markdown]
# ### Model 2 Training
#
# Train your second model on the training dataset.
#
# **Instructions:**
# - Fit the second model to the training data.
# - Ensure to monitor the training process.

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN,Dense,Dropout,Input

from keras.callbacks import EarlyStopping

# %%
model_rnn = Sequential([
    Input(shape=(X_train.shape[1],1)),
    SimpleRNN(units=25, return_sequences=True),
    Dropout(0.25),
    
    SimpleRNN(units=25),
    Dropout(0.25),
    
    
    # SimpleRNN(units=50, return_sequences=True)
    # Dropout(0.25)
    
    Dense(units=1)
])

model_rnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 17, 25)         │           675 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 17, 25)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,976 (7.72 KB)
#  Trainable params: 1,976 (7.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_rnn.compile(loss='mean_squared_error',optimizer='adam',metrics=['mean_squared_error'])

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=10, restore_best_weights=True)

model_rnn.fit(X_train,y_train,epochs=2000,validation_split=0.2,callbacks=early_stopping)
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 215.3896 - mean_squared_error: 215.3896 - val_loss: 198.3204 - val_mean_squared_error: 198.3204
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 209.5143 - mean_squared_error: 209.5143 - val_loss: 196.4581 - val_mean_squared_error: 196.4581
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 219.8186 - mean_squared_error: 219.8186 - val_loss: 194.6054 - val_mean_squared_error: 194.6054
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 215.2500 - mean_squared_error: 215.2500 - val_loss: 192.7738 - val_mean_squared_error: 192.7738
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 218.2341 - mean_squared_error: 218.2341 - val_loss: 190.9578 - val_mean_squared_error: 190.9578
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 205.7329 - mean_squared_error: 205.7329 - val_loss: 189.1577 - val_mean_squared_error: 189.1577
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 205.8167 - mean_squared_error: 205.8167 - val_loss: 187.3804 - val_mean_squared_error: 187.3804
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 206.9230 - mean_squared_error: 206.9230 - val_loss: 185.6117 - val_mean_squared_error: 185.6117
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 201.3491 - mean_squared_error: 201.3491 - val_loss: 183.8578 - val_mean_squared_error: 183.8578
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 196.3657 - mean_squared_error: 196.3657 - val_loss: 182.1217 - val_mean_squared_error: 182.1217
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 209.2983 - mean_squared_error: 209.2983 - val_loss: 180.4009 - val_mean_squared_error: 180.4009
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 193.9371 - mean_squared_error: 193.9371 - val_loss: 178.6925 - val_mean_squared_error: 178.6925
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 186.5746 - mean_squared_error: 186.5746 - val_loss: 176.9946 - val_mean_squared_error: 176.9946
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 194.4501 - mean_squared_error: 194.4501 - val_loss: 175.3035 - val_mean_squared_error: 175.3035
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 197.6355 - mean_squared_error: 197.6355 - val_loss: 173.6356 - val_mean_squared_error: 173.6356
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 187.9550 - mean_squared_error: 187.9550 - val_loss: 171.9828 - val_mean_squared_error: 171.9828
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 188.1187 - mean_squared_error: 188.1187 - val_loss: 170.3381 - val_mean_squared_error: 170.3381
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 193.6731 - mean_squared_error: 193.6731 - val_loss: 168.7009 - val_mean_squared_error: 168.7009
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 185.9626 - mean_squared_error: 185.9626 - val_loss: 167.0781 - val_mean_squared_error: 167.0781
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 186.0563 - mean_squared_error: 186.0563 - val_loss: 165.4712 - val_mean_squared_error: 165.4712
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 175.7288 - mean_squared_error: 175.7288 - val_loss: 163.8753 - val_mean_squared_error: 163.8753
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 183.8524 - mean_squared_error: 183.8524 - val_loss: 162.2873 - val_mean_squared_error: 162.2873
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 180.1891 - mean_squared_error: 180.1891 - val_loss: 160.7120 - val_mean_squared_error: 160.7120
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 176.9984 - mean_squared_error: 176.9984 - val_loss: 159.1562 - val_mean_squared_error: 159.1562
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 167.8826 - mean_squared_error: 167.8826 - val_loss: 157.6159 - val_mean_squared_error: 157.6159
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 166.6931 - mean_squared_error: 166.6931 - val_loss: 156.0853 - val_mean_squared_error: 156.0853
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 187.0659 - mean_squared_error: 187.0659 - val_loss: 154.5618 - val_mean_squared_error: 154.5618
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 159.6554 - mean_squared_error: 159.6554 - val_loss: 153.0601 - val_mean_squared_error: 153.0601
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 170.1400 - mean_squared_error: 170.1400 - val_loss: 151.5569 - val_mean_squared_error: 151.5569
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 173.5624 - mean_squared_error: 173.5624 - val_loss: 150.0659 - val_mean_squared_error: 150.0659
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 161.8625 - mean_squared_error: 161.8625 - val_loss: 148.5924 - val_mean_squared_error: 148.5924
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 153.1441 - mean_squared_error: 153.1441 - val_loss: 147.1228 - val_mean_squared_error: 147.1228
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 157.9053 - mean_squared_error: 157.9053 - val_loss: 145.6650 - val_mean_squared_error: 145.6650
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 159.1410 - mean_squared_error: 159.1410 - val_loss: 144.2148 - val_mean_squared_error: 144.2148
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 158.6039 - mean_squared_error: 158.6039 - val_loss: 142.7813 - val_mean_squared_error: 142.7813
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 155.0761 - mean_squared_error: 155.0761 - val_loss: 141.3642 - val_mean_squared_error: 141.3642
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 165.6895 - mean_squared_error: 165.6895 - val_loss: 139.9632 - val_mean_squared_error: 139.9632
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 150.3232 - mean_squared_error: 150.3232 - val_loss: 138.5829 - val_mean_squared_error: 138.5829
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 155.7288 - mean_squared_error: 155.7288 - val_loss: 137.2041 - val_mean_squared_error: 137.2041
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 157.7503 - mean_squared_error: 157.7503 - val_loss: 135.8341 - val_mean_squared_error: 135.8341
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 156.0211 - mean_squared_error: 156.0211 - val_loss: 134.4773 - val_mean_squared_error: 134.4773
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 151.3824 - mean_squared_error: 151.3824 - val_loss: 133.1313 - val_mean_squared_error: 133.1313
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 151.2031 - mean_squared_error: 151.2031 - val_loss: 131.7970 - val_mean_squared_error: 131.7970
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 146.5722 - mean_squared_error: 146.5722 - val_loss: 130.4819 - val_mean_squared_error: 130.4819
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 144.4679 - mean_squared_error: 144.4679 - val_loss: 129.1749 - val_mean_squared_error: 129.1749
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 150.6281 - mean_squared_error: 150.6281 - val_loss: 127.8710 - val_mean_squared_error: 127.8710
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 131.4234 - mean_squared_error: 131.4234 - val_loss: 126.5826 - val_mean_squared_error: 126.5826
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 149.7261 - mean_squared_error: 149.7261 - val_loss: 125.3018 - val_mean_squared_error: 125.3018
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 149.6234 - mean_squared_error: 149.6234 - val_loss: 124.0363 - val_mean_squared_error: 124.0363
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 151.1362 - mean_squared_error: 151.1362 - val_loss: 122.7771 - val_mean_squared_error: 122.7771
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 137.5409 - mean_squared_error: 137.5409 - val_loss: 121.5304 - val_mean_squared_error: 121.5304
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 143.6625 - mean_squared_error: 143.6625 - val_loss: 120.2890 - val_mean_squared_error: 120.2890
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 143.6492 - mean_squared_error: 143.6492 - val_loss: 119.0543 - val_mean_squared_error: 119.0543
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 144.3642 - mean_squared_error: 144.3642 - val_loss: 117.8378 - val_mean_squared_error: 117.8378
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 128.3712 - mean_squared_error: 128.3712 - val_loss: 116.6328 - val_mean_squared_error: 116.6328
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 131.1167 - mean_squared_error: 131.1167 - val_loss: 115.4317 - val_mean_squared_error: 115.4317
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 117.2770 - mean_squared_error: 117.2770 - val_loss: 114.2461 - val_mean_squared_error: 114.2461
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 143.1666 - mean_squared_error: 143.1666 - val_loss: 113.0624 - val_mean_squared_error: 113.0624
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 127.2431 - mean_squared_error: 127.2431 - val_loss: 111.9051 - val_mean_squared_error: 111.9051
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 123.5593 - mean_squared_error: 123.5593 - val_loss: 110.7557 - val_mean_squared_error: 110.7557
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 120.1251 - mean_squared_error: 120.1251 - val_loss: 109.6142 - val_mean_squared_error: 109.6142
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 123.7892 - mean_squared_error: 123.7892 - val_loss: 108.4814 - val_mean_squared_error: 108.4814
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 119.8869 - mean_squared_error: 119.8869 - val_loss: 107.3605 - val_mean_squared_error: 107.3605
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 132.0218 - mean_squared_error: 132.0218 - val_loss: 106.2508 - val_mean_squared_error: 106.2508
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 124.2969 - mean_squared_error: 124.2969 - val_loss: 105.1591 - val_mean_squared_error: 105.1591
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 115.5533 - mean_squared_error: 115.5533 - val_loss: 104.0787 - val_mean_squared_error: 104.0787
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 116.6665 - mean_squared_error: 116.6665 - val_loss: 103.0022 - val_mean_squared_error: 103.0022
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 114.8223 - mean_squared_error: 114.8223 - val_loss: 101.9367 - val_mean_squared_error: 101.9367
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 119.5475 - mean_squared_error: 119.5475 - val_loss: 100.8783 - val_mean_squared_error: 100.8783
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 117.9350 - mean_squared_error: 117.9350 - val_loss: 99.8218 - val_mean_squared_error: 99.8218
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 114.3061 - mean_squared_error: 114.3061 - val_loss: 98.7766 - val_mean_squared_error: 98.7766
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 113.1385 - mean_squared_error: 113.1385 - val_loss: 97.7498 - val_mean_squared_error: 97.7498
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 117.2483 - mean_squared_error: 117.2483 - val_loss: 96.7330 - val_mean_squared_error: 96.7330
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 110.0555 - mean_squared_error: 110.0555 - val_loss: 95.7229 - val_mean_squared_error: 95.7229
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 118.1455 - mean_squared_error: 118.1455 - val_loss: 94.7114 - val_mean_squared_error: 94.7114
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 102.8170 - mean_squared_error: 102.8170 - val_loss: 93.7196 - val_mean_squared_error: 93.7196
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 112.3477 - mean_squared_error: 112.3477 - val_loss: 92.7410 - val_mean_squared_error: 92.7410
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 111.9772 - mean_squared_error: 111.9772 - val_loss: 91.7610 - val_mean_squared_error: 91.7610
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 98.5968 - mean_squared_error: 98.5968 - val_loss: 90.7949 - val_mean_squared_error: 90.7949
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 105.9995 - mean_squared_error: 105.9995 - val_loss: 89.8264 - val_mean_squared_error: 89.8264
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 95.5982 - mean_squared_error: 95.5982 - val_loss: 88.8709 - val_mean_squared_error: 88.8709
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 101.4048 - mean_squared_error: 101.4048 - val_loss: 87.9221 - val_mean_squared_error: 87.9221
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 108.4710 - mean_squared_error: 108.4710 - val_loss: 86.9795 - val_mean_squared_error: 86.9795
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 104.3976 - mean_squared_error: 104.3976 - val_loss: 86.0513 - val_mean_squared_error: 86.0513
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 92.4285 - mean_squared_error: 92.4285 - val_loss: 85.1370 - val_mean_squared_error: 85.1370
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 108.6758 - mean_squared_error: 108.6758 - val_loss: 84.2256 - val_mean_squared_error: 84.2256
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 98.4536 - mean_squared_error: 98.4536 - val_loss: 83.3221 - val_mean_squared_error: 83.3221
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 105.6156 - mean_squared_error: 105.6156 - val_loss: 82.4251 - val_mean_squared_error: 82.4251
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 97.5689 - mean_squared_error: 97.5689 - val_loss: 81.5417 - val_mean_squared_error: 81.5417
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 97.7509 - mean_squared_error: 97.7509 - val_loss: 80.6684 - val_mean_squared_error: 80.6684
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 100.3260 - mean_squared_error: 100.3260 - val_loss: 79.8070 - val_mean_squared_error: 79.8070
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 97.6074 - mean_squared_error: 97.6074 - val_loss: 78.9519 - val_mean_squared_error: 78.9519
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 95.0400 - mean_squared_error: 95.0400 - val_loss: 78.0962 - val_mean_squared_error: 78.0962
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 96.2077 - mean_squared_error: 96.2077 - val_loss: 77.2515 - val_mean_squared_error: 77.2515
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 94.8711 - mean_squared_error: 94.8711 - val_loss: 76.4088 - val_mean_squared_error: 76.4088
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 96.3087 - mean_squared_error: 96.3087 - val_loss: 75.5740 - val_mean_squared_error: 75.5740
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 94.2673 - mean_squared_error: 94.2673 - val_loss: 74.7449 - val_mean_squared_error: 74.7449
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 90.0374 - mean_squared_error: 90.0374 - val_loss: 73.9246 - val_mean_squared_error: 73.9246
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 98.9540 - mean_squared_error: 98.9540 - val_loss: 73.1106 - val_mean_squared_error: 73.1106
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 92.0483 - mean_squared_error: 92.0483 - val_loss: 72.3059 - val_mean_squared_error: 72.3059
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 92.8065 - mean_squared_error: 92.8065 - val_loss: 71.5061 - val_mean_squared_error: 71.5061
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 102.9779 - mean_squared_error: 102.9779 - val_loss: 70.7080 - val_mean_squared_error: 70.7080
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 92.5055 - mean_squared_error: 92.5055 - val_loss: 69.9257 - val_mean_squared_error: 69.9257
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 91.9881 - mean_squared_error: 91.9881 - val_loss: 69.1496 - val_mean_squared_error: 69.1496
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 78.7958 - mean_squared_error: 78.7958 - val_loss: 68.3819 - val_mean_squared_error: 68.3819
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 89.9228 - mean_squared_error: 89.9228 - val_loss: 67.6101 - val_mean_squared_error: 67.6101
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 82.8684 - mean_squared_error: 82.8684 - val_loss: 66.8559 - val_mean_squared_error: 66.8559
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 84.1551 - mean_squared_error: 84.1551 - val_loss: 66.1078 - val_mean_squared_error: 66.1078
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 83.9661 - mean_squared_error: 83.9661 - val_loss: 65.3692 - val_mean_squared_error: 65.3692
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 83.3403 - mean_squared_error: 83.3403 - val_loss: 64.6358 - val_mean_squared_error: 64.6358
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 80.9710 - mean_squared_error: 80.9710 - val_loss: 63.9139 - val_mean_squared_error: 63.9139
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 85.3672 - mean_squared_error: 85.3672 - val_loss: 63.1955 - val_mean_squared_error: 63.1955
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 86.1100 - mean_squared_error: 86.1100 - val_loss: 62.4796 - val_mean_squared_error: 62.4796
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 79.9690 - mean_squared_error: 79.9690 - val_loss: 61.7720 - val_mean_squared_error: 61.7720
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 85.2731 - mean_squared_error: 85.2731 - val_loss: 61.0726 - val_mean_squared_error: 61.0726
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 74.2671 - mean_squared_error: 74.2671 - val_loss: 60.3860 - val_mean_squared_error: 60.3860
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 76.3918 - mean_squared_error: 76.3918 - val_loss: 59.7123 - val_mean_squared_error: 59.7123
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 73.5227 - mean_squared_error: 73.5227 - val_loss: 59.0428 - val_mean_squared_error: 59.0428
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 77.7310 - mean_squared_error: 77.7310 - val_loss: 58.3782 - val_mean_squared_error: 58.3782
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 68.5345 - mean_squared_error: 68.5345 - val_loss: 57.7198 - val_mean_squared_error: 57.7198
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 79.3460 - mean_squared_error: 79.3460 - val_loss: 57.0533 - val_mean_squared_error: 57.0533
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 73.1281 - mean_squared_error: 73.1281 - val_loss: 56.3976 - val_mean_squared_error: 56.3976
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 82.9829 - mean_squared_error: 82.9829 - val_loss: 55.7452 - val_mean_squared_error: 55.7452
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 73.0000 - mean_squared_error: 73.0000 - val_loss: 55.0969 - val_mean_squared_error: 55.0969
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 76.6752 - mean_squared_error: 76.6752 - val_loss: 54.4558 - val_mean_squared_error: 54.4558
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 62.8567 - mean_squared_error: 62.8567 - val_loss: 53.8301 - val_mean_squared_error: 53.8301
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 69.5694 - mean_squared_error: 69.5694 - val_loss: 53.2073 - val_mean_squared_error: 53.2073
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 73.5698 - mean_squared_error: 73.5698 - val_loss: 52.5902 - val_mean_squared_error: 52.5902
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 61.4026 - mean_squared_error: 61.4026 - val_loss: 51.9855 - val_mean_squared_error: 51.9855
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 67.5393 - mean_squared_error: 67.5393 - val_loss: 51.3880 - val_mean_squared_error: 51.3880
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 60.1609 - mean_squared_error: 60.1609 - val_loss: 50.7939 - val_mean_squared_error: 50.7939
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 59.0496 - mean_squared_error: 59.0496 - val_loss: 50.2053 - val_mean_squared_error: 50.2053
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 62.9285 - mean_squared_error: 62.9285 - val_loss: 49.6338 - val_mean_squared_error: 49.6338
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 68.0637 - mean_squared_error: 68.0637 - val_loss: 49.0605 - val_mean_squared_error: 49.0605
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 62.9886 - mean_squared_error: 62.9886 - val_loss: 48.4980 - val_mean_squared_error: 48.4980
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 71.3241 - mean_squared_error: 71.3241 - val_loss: 47.9362 - val_mean_squared_error: 47.9362
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 62.2463 - mean_squared_error: 62.2463 - val_loss: 47.3803 - val_mean_squared_error: 47.3803
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 58.9462 - mean_squared_error: 58.9462 - val_loss: 46.8368 - val_mean_squared_error: 46.8368
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 66.9956 - mean_squared_error: 66.9956 - val_loss: 46.2961 - val_mean_squared_error: 46.2961
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 63.3757 - mean_squared_error: 63.3757 - val_loss: 45.7611 - val_mean_squared_error: 45.7611
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 64.8443 - mean_squared_error: 64.8443 - val_loss: 45.2254 - val_mean_squared_error: 45.2254
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 61.9127 - mean_squared_error: 61.9127 - val_loss: 44.6942 - val_mean_squared_error: 44.6942
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 64.0768 - mean_squared_error: 64.0768 - val_loss: 44.1716 - val_mean_squared_error: 44.1716
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 65.4865 - mean_squared_error: 65.4865 - val_loss: 43.6448 - val_mean_squared_error: 43.6448
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 58.7386 - mean_squared_error: 58.7386 - val_loss: 43.1258 - val_mean_squared_error: 43.1258
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 59.1472 - mean_squared_error: 59.1472 - val_loss: 42.6114 - val_mean_squared_error: 42.6114
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.3160 - mean_squared_error: 48.3160 - val_loss: 42.1114 - val_mean_squared_error: 42.1114
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 60.6957 - mean_squared_error: 60.6957 - val_loss: 41.6164 - val_mean_squared_error: 41.6164
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 57.8931 - mean_squared_error: 57.8931 - val_loss: 41.1297 - val_mean_squared_error: 41.1297
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 53.9417 - mean_squared_error: 53.9417 - val_loss: 40.6468 - val_mean_squared_error: 40.6468
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 55.7199 - mean_squared_error: 55.7199 - val_loss: 40.1700 - val_mean_squared_error: 40.1700
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 54.5467 - mean_squared_error: 54.5467 - val_loss: 39.7007 - val_mean_squared_error: 39.7007
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 62.9194 - mean_squared_error: 62.9194 - val_loss: 39.2331 - val_mean_squared_error: 39.2331
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.9138 - mean_squared_error: 50.9138 - val_loss: 38.7716 - val_mean_squared_error: 38.7716
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 53.1785 - mean_squared_error: 53.1785 - val_loss: 38.3106 - val_mean_squared_error: 38.3106
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 52.8268 - mean_squared_error: 52.8268 - val_loss: 37.8513 - val_mean_squared_error: 37.8513
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.0174 - mean_squared_error: 45.0174 - val_loss: 37.4003 - val_mean_squared_error: 37.4003
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 51.9498 - mean_squared_error: 51.9498 - val_loss: 36.9593 - val_mean_squared_error: 36.9593
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 52.2219 - mean_squared_error: 52.2219 - val_loss: 36.5231 - val_mean_squared_error: 36.5231
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 57.6859 - mean_squared_error: 57.6859 - val_loss: 36.0888 - val_mean_squared_error: 36.0888
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 46.2999 - mean_squared_error: 46.2999 - val_loss: 35.6619 - val_mean_squared_error: 35.6619
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 50.2810 - mean_squared_error: 50.2810 - val_loss: 35.2370 - val_mean_squared_error: 35.2370
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 43.8473 - mean_squared_error: 43.8473 - val_loss: 34.8178 - val_mean_squared_error: 34.8178
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 47.9566 - mean_squared_error: 47.9566 - val_loss: 34.4018 - val_mean_squared_error: 34.4018
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.1839 - mean_squared_error: 48.1839 - val_loss: 33.9940 - val_mean_squared_error: 33.9940
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 47.6291 - mean_squared_error: 47.6291 - val_loss: 33.5879 - val_mean_squared_error: 33.5879
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 51.5999 - mean_squared_error: 51.5999 - val_loss: 33.1874 - val_mean_squared_error: 33.1874
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 47.9226 - mean_squared_error: 47.9226 - val_loss: 32.7852 - val_mean_squared_error: 32.7852
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 53.4021 - mean_squared_error: 53.4021 - val_loss: 32.3882 - val_mean_squared_error: 32.3882
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 53.1238 - mean_squared_error: 53.1238 - val_loss: 31.9891 - val_mean_squared_error: 31.9891
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 44.1798 - mean_squared_error: 44.1798 - val_loss: 31.6028 - val_mean_squared_error: 31.6028
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 53.7393 - mean_squared_error: 53.7393 - val_loss: 31.2266 - val_mean_squared_error: 31.2266
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 49.3804 - mean_squared_error: 49.3804 - val_loss: 30.8538 - val_mean_squared_error: 30.8538
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.0793 - mean_squared_error: 50.0793 - val_loss: 30.4853 - val_mean_squared_error: 30.4853
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 46.0742 - mean_squared_error: 46.0742 - val_loss: 30.1202 - val_mean_squared_error: 30.1202
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 50.5592 - mean_squared_error: 50.5592 - val_loss: 29.7632 - val_mean_squared_error: 29.7632
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 55.9390 - mean_squared_error: 55.9390 - val_loss: 29.4053 - val_mean_squared_error: 29.4053
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 43.1543 - mean_squared_error: 43.1543 - val_loss: 29.0548 - val_mean_squared_error: 29.0548
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 50.2106 - mean_squared_error: 50.2106 - val_loss: 28.7092 - val_mean_squared_error: 28.7092
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 49.1711 - mean_squared_error: 49.1711 - val_loss: 28.3656 - val_mean_squared_error: 28.3656
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 43.0440 - mean_squared_error: 43.0440 - val_loss: 28.0281 - val_mean_squared_error: 28.0281
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 46.6318 - mean_squared_error: 46.6318 - val_loss: 27.6906 - val_mean_squared_error: 27.6906
# Epoch 183/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 52.1064 - mean_squared_error: 52.1064 - val_loss: 27.3518 - val_mean_squared_error: 27.3518
# Epoch 184/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 43.7949 - mean_squared_error: 43.7949 - val_loss: 27.0194 - val_mean_squared_error: 27.0194
# Epoch 185/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 47.2290 - mean_squared_error: 47.2290 - val_loss: 26.6912 - val_mean_squared_error: 26.6912
# Epoch 186/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 39.8043 - mean_squared_error: 39.8043 - val_loss: 26.3702 - val_mean_squared_error: 26.3702
# Epoch 187/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.5246 - mean_squared_error: 36.5246 - val_loss: 26.0517 - val_mean_squared_error: 26.0517
# Epoch 188/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 41.6798 - mean_squared_error: 41.6798 - val_loss: 25.7379 - val_mean_squared_error: 25.7379
# Epoch 189/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 44.1476 - mean_squared_error: 44.1476 - val_loss: 25.4316 - val_mean_squared_error: 25.4316
# Epoch 190/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 43.0109 - mean_squared_error: 43.0109 - val_loss: 25.1317 - val_mean_squared_error: 25.1317
# Epoch 191/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37.9776 - mean_squared_error: 37.9776 - val_loss: 24.8326 - val_mean_squared_error: 24.8326
# Epoch 192/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 43.2252 - mean_squared_error: 43.2252 - val_loss: 24.5379 - val_mean_squared_error: 24.5379
# Epoch 193/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 39.1577 - mean_squared_error: 39.1577 - val_loss: 24.2440 - val_mean_squared_error: 24.2440
# Epoch 194/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 41.3076 - mean_squared_error: 41.3076 - val_loss: 23.9604 - val_mean_squared_error: 23.9604
# Epoch 195/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 37.6557 - mean_squared_error: 37.6557 - val_loss: 23.6810 - val_mean_squared_error: 23.6810
# Epoch 196/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 38.3172 - mean_squared_error: 38.3172 - val_loss: 23.4014 - val_mean_squared_error: 23.4014
# Epoch 197/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 34.9283 - mean_squared_error: 34.9283 - val_loss: 23.1213 - val_mean_squared_error: 23.1213
# Epoch 198/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.1601 - mean_squared_error: 38.1601 - val_loss: 22.8414 - val_mean_squared_error: 22.8414
# Epoch 199/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 43.8948 - mean_squared_error: 43.8948 - val_loss: 22.5691 - val_mean_squared_error: 22.5691
# Epoch 200/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 44.9851 - mean_squared_error: 44.9851 - val_loss: 22.2934 - val_mean_squared_error: 22.2934
# Epoch 201/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 43.8794 - mean_squared_error: 43.8794 - val_loss: 22.0201 - val_mean_squared_error: 22.0201
# Epoch 202/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 41.9119 - mean_squared_error: 41.9119 - val_loss: 21.7494 - val_mean_squared_error: 21.7494
# Epoch 203/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 37.9318 - mean_squared_error: 37.9318 - val_loss: 21.4790 - val_mean_squared_error: 21.4790
# Epoch 204/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 31.4408 - mean_squared_error: 31.4408 - val_loss: 21.2145 - val_mean_squared_error: 21.2145
# Epoch 205/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 35.5788 - mean_squared_error: 35.5788 - val_loss: 20.9534 - val_mean_squared_error: 20.9534
# Epoch 206/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 41.2475 - mean_squared_error: 41.2475 - val_loss: 20.6931 - val_mean_squared_error: 20.6931
# Epoch 207/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 40.4580 - mean_squared_error: 40.4580 - val_loss: 20.4353 - val_mean_squared_error: 20.4353
# Epoch 208/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 37.0837 - mean_squared_error: 37.0837 - val_loss: 20.1819 - val_mean_squared_error: 20.1819
# Epoch 209/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 42.1139 - mean_squared_error: 42.1139 - val_loss: 19.9372 - val_mean_squared_error: 19.9372
# Epoch 210/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 39.3887 - mean_squared_error: 39.3887 - val_loss: 19.6976 - val_mean_squared_error: 19.6976
# Epoch 211/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 34.9717 - mean_squared_error: 34.9717 - val_loss: 19.4659 - val_mean_squared_error: 19.4659
# Epoch 212/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 38.1313 - mean_squared_error: 38.1313 - val_loss: 19.2345 - val_mean_squared_error: 19.2345
# Epoch 213/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 36.5113 - mean_squared_error: 36.5113 - val_loss: 19.0106 - val_mean_squared_error: 19.0106
# Epoch 214/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 39.6163 - mean_squared_error: 39.6163 - val_loss: 18.7861 - val_mean_squared_error: 18.7861
# Epoch 215/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 36.1775 - mean_squared_error: 36.1775 - val_loss: 18.5622 - val_mean_squared_error: 18.5622
# Epoch 216/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 35.3693 - mean_squared_error: 35.3693 - val_loss: 18.3404 - val_mean_squared_error: 18.3404
# Epoch 217/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.8886 - mean_squared_error: 33.8886 - val_loss: 18.1200 - val_mean_squared_error: 18.1200
# Epoch 218/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 37.2203 - mean_squared_error: 37.2203 - val_loss: 17.8980 - val_mean_squared_error: 17.8980
# Epoch 219/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 38.5495 - mean_squared_error: 38.5495 - val_loss: 17.6815 - val_mean_squared_error: 17.6815
# Epoch 220/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 41.2024 - mean_squared_error: 41.2024 - val_loss: 17.4637 - val_mean_squared_error: 17.4637
# Epoch 221/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 36.2433 - mean_squared_error: 36.2433 - val_loss: 17.2497 - val_mean_squared_error: 17.2497
# Epoch 222/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 30.1043 - mean_squared_error: 30.1043 - val_loss: 17.0446 - val_mean_squared_error: 17.0446
# Epoch 223/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 35.7778 - mean_squared_error: 35.7778 - val_loss: 16.8379 - val_mean_squared_error: 16.8379
# Epoch 224/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 41.8293 - mean_squared_error: 41.8293 - val_loss: 16.6291 - val_mean_squared_error: 16.6291
# Epoch 225/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.2678 - mean_squared_error: 32.2678 - val_loss: 16.4292 - val_mean_squared_error: 16.4292
# Epoch 226/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 34.3931 - mean_squared_error: 34.3931 - val_loss: 16.2321 - val_mean_squared_error: 16.2321
# Epoch 227/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 36.4642 - mean_squared_error: 36.4642 - val_loss: 16.0350 - val_mean_squared_error: 16.0350
# Epoch 228/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 27.6236 - mean_squared_error: 27.6236 - val_loss: 15.8415 - val_mean_squared_error: 15.8415
# Epoch 229/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.1106 - mean_squared_error: 32.1106 - val_loss: 15.6522 - val_mean_squared_error: 15.6522
# Epoch 230/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 34.2886 - mean_squared_error: 34.2886 - val_loss: 15.4658 - val_mean_squared_error: 15.4658
# Epoch 231/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.3648 - mean_squared_error: 28.3648 - val_loss: 15.2874 - val_mean_squared_error: 15.2874
# Epoch 232/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.7039 - mean_squared_error: 30.7039 - val_loss: 15.1081 - val_mean_squared_error: 15.1081
# Epoch 233/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.8074 - mean_squared_error: 27.8074 - val_loss: 14.9319 - val_mean_squared_error: 14.9319
# Epoch 234/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.3413 - mean_squared_error: 33.3413 - val_loss: 14.7612 - val_mean_squared_error: 14.7612
# Epoch 235/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.3259 - mean_squared_error: 29.3259 - val_loss: 14.5966 - val_mean_squared_error: 14.5966
# Epoch 236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 28.7395 - mean_squared_error: 28.7395 - val_loss: 14.4336 - val_mean_squared_error: 14.4336
# Epoch 237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.0342 - mean_squared_error: 31.0342 - val_loss: 14.2693 - val_mean_squared_error: 14.2693
# Epoch 238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.2598 - mean_squared_error: 34.2598 - val_loss: 14.1015 - val_mean_squared_error: 14.1015
# Epoch 239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.8012 - mean_squared_error: 32.8012 - val_loss: 13.9383 - val_mean_squared_error: 13.9383
# Epoch 240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.4186 - mean_squared_error: 26.4186 - val_loss: 13.7826 - val_mean_squared_error: 13.7826
# Epoch 241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.1139 - mean_squared_error: 33.1139 - val_loss: 13.6254 - val_mean_squared_error: 13.6254
# Epoch 242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.2238 - mean_squared_error: 33.2238 - val_loss: 13.4651 - val_mean_squared_error: 13.4651
# Epoch 243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 34.6073 - mean_squared_error: 34.6073 - val_loss: 13.3088 - val_mean_squared_error: 13.3088
# Epoch 244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.6857 - mean_squared_error: 28.6857 - val_loss: 13.1490 - val_mean_squared_error: 13.1490
# Epoch 245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.1937 - mean_squared_error: 33.1937 - val_loss: 12.9911 - val_mean_squared_error: 12.9911
# Epoch 246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.5907 - mean_squared_error: 28.5907 - val_loss: 12.8352 - val_mean_squared_error: 12.8352
# Epoch 247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33.6326 - mean_squared_error: 33.6326 - val_loss: 12.6844 - val_mean_squared_error: 12.6844
# Epoch 248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.7010 - mean_squared_error: 25.7010 - val_loss: 12.5396 - val_mean_squared_error: 12.5396
# Epoch 249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.5936 - mean_squared_error: 30.5936 - val_loss: 12.3975 - val_mean_squared_error: 12.3975
# Epoch 250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 23.6491 - mean_squared_error: 23.6491 - val_loss: 12.2595 - val_mean_squared_error: 12.2595
# Epoch 251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 33.1386 - mean_squared_error: 33.1386 - val_loss: 12.1244 - val_mean_squared_error: 12.1244
# Epoch 252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.1386 - mean_squared_error: 31.1386 - val_loss: 11.9894 - val_mean_squared_error: 11.9894
# Epoch 253/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.1544 - mean_squared_error: 28.1544 - val_loss: 11.8545 - val_mean_squared_error: 11.8545
# Epoch 254/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.2521 - mean_squared_error: 31.2521 - val_loss: 11.7141 - val_mean_squared_error: 11.7141
# Epoch 255/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.4523 - mean_squared_error: 31.4523 - val_loss: 11.5715 - val_mean_squared_error: 11.5715
# Epoch 256/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 37.5805 - mean_squared_error: 37.5805 - val_loss: 11.4319 - val_mean_squared_error: 11.4319
# Epoch 257/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 27.9107 - mean_squared_error: 27.9107 - val_loss: 11.3005 - val_mean_squared_error: 11.3005
# Epoch 258/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.9932 - mean_squared_error: 27.9932 - val_loss: 11.1706 - val_mean_squared_error: 11.1706
# Epoch 259/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.4523 - mean_squared_error: 31.4523 - val_loss: 11.0454 - val_mean_squared_error: 11.0454
# Epoch 260/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.2587 - mean_squared_error: 32.2587 - val_loss: 10.9150 - val_mean_squared_error: 10.9150
# Epoch 261/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.6089 - mean_squared_error: 25.6089 - val_loss: 10.7865 - val_mean_squared_error: 10.7865
# Epoch 262/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 27.3862 - mean_squared_error: 27.3862 - val_loss: 10.6610 - val_mean_squared_error: 10.6610
# Epoch 263/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.4969 - mean_squared_error: 31.4969 - val_loss: 10.5400 - val_mean_squared_error: 10.5400
# Epoch 264/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.6773 - mean_squared_error: 29.6773 - val_loss: 10.4196 - val_mean_squared_error: 10.4196
# Epoch 265/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28.6765 - mean_squared_error: 28.6765 - val_loss: 10.2973 - val_mean_squared_error: 10.2973
# Epoch 266/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.1620 - mean_squared_error: 25.1620 - val_loss: 10.1803 - val_mean_squared_error: 10.1803
# Epoch 267/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.3763 - mean_squared_error: 27.3763 - val_loss: 10.0642 - val_mean_squared_error: 10.0642
# Epoch 268/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.5227 - mean_squared_error: 27.5227 - val_loss: 9.9488 - val_mean_squared_error: 9.9488
# Epoch 269/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32.2612 - mean_squared_error: 32.2612 - val_loss: 9.8338 - val_mean_squared_error: 9.8338
# Epoch 270/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.0389 - mean_squared_error: 33.0389 - val_loss: 9.7226 - val_mean_squared_error: 9.7226
# Epoch 271/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.6840 - mean_squared_error: 29.6840 - val_loss: 9.6097 - val_mean_squared_error: 9.6097
# Epoch 272/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.7176 - mean_squared_error: 25.7176 - val_loss: 9.4983 - val_mean_squared_error: 9.4983
# Epoch 273/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.4815 - mean_squared_error: 23.4815 - val_loss: 9.3911 - val_mean_squared_error: 9.3911
# Epoch 274/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.2557 - mean_squared_error: 23.2557 - val_loss: 9.2897 - val_mean_squared_error: 9.2897
# Epoch 275/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 28.5684 - mean_squared_error: 28.5684 - val_loss: 9.1902 - val_mean_squared_error: 9.1902
# Epoch 276/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.3132 - mean_squared_error: 29.3132 - val_loss: 9.0897 - val_mean_squared_error: 9.0897
# Epoch 277/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.7999 - mean_squared_error: 22.7999 - val_loss: 8.9922 - val_mean_squared_error: 8.9922
# Epoch 278/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.6356 - mean_squared_error: 27.6356 - val_loss: 8.8945 - val_mean_squared_error: 8.8945
# Epoch 279/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.5696 - mean_squared_error: 22.5696 - val_loss: 8.7994 - val_mean_squared_error: 8.7994
# Epoch 280/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.1906 - mean_squared_error: 19.1906 - val_loss: 8.7064 - val_mean_squared_error: 8.7064
# Epoch 281/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.2618 - mean_squared_error: 25.2618 - val_loss: 8.6136 - val_mean_squared_error: 8.6136
# Epoch 282/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.4247 - mean_squared_error: 26.4247 - val_loss: 8.5255 - val_mean_squared_error: 8.5255
# Epoch 283/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 31.1484 - mean_squared_error: 31.1484 - val_loss: 8.4354 - val_mean_squared_error: 8.4354
# Epoch 284/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 24.9760 - mean_squared_error: 24.9760 - val_loss: 8.3487 - val_mean_squared_error: 8.3487
# Epoch 285/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 23.4437 - mean_squared_error: 23.4437 - val_loss: 8.2665 - val_mean_squared_error: 8.2665
# Epoch 286/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.9775 - mean_squared_error: 26.9775 - val_loss: 8.1835 - val_mean_squared_error: 8.1835
# Epoch 287/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.8054 - mean_squared_error: 21.8054 - val_loss: 8.1002 - val_mean_squared_error: 8.1002
# Epoch 288/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.6807 - mean_squared_error: 29.6807 - val_loss: 8.0092 - val_mean_squared_error: 8.0092
# Epoch 289/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.1587 - mean_squared_error: 27.1587 - val_loss: 7.9170 - val_mean_squared_error: 7.9170
# Epoch 290/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 22.2176 - mean_squared_error: 22.2176 - val_loss: 7.8322 - val_mean_squared_error: 7.8322
# Epoch 291/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.2207 - mean_squared_error: 27.2207 - val_loss: 7.7535 - val_mean_squared_error: 7.7535
# Epoch 292/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 22.0190 - mean_squared_error: 22.0190 - val_loss: 7.6767 - val_mean_squared_error: 7.6767
# Epoch 293/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.0348 - mean_squared_error: 21.0348 - val_loss: 7.5999 - val_mean_squared_error: 7.5999
# Epoch 294/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.3255 - mean_squared_error: 23.3255 - val_loss: 7.5213 - val_mean_squared_error: 7.5213
# Epoch 295/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.6580 - mean_squared_error: 25.6580 - val_loss: 7.4411 - val_mean_squared_error: 7.4411
# Epoch 296/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.1923 - mean_squared_error: 23.1923 - val_loss: 7.3592 - val_mean_squared_error: 7.3592
# Epoch 297/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 25.3530 - mean_squared_error: 25.3530 - val_loss: 7.2793 - val_mean_squared_error: 7.2793
# Epoch 298/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.8395 - mean_squared_error: 26.8395 - val_loss: 7.2048 - val_mean_squared_error: 7.2048
# Epoch 299/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.3518 - mean_squared_error: 23.3518 - val_loss: 7.1278 - val_mean_squared_error: 7.1278
# Epoch 300/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.8575 - mean_squared_error: 20.8575 - val_loss: 7.0571 - val_mean_squared_error: 7.0571
# Epoch 301/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.0201 - mean_squared_error: 24.0201 - val_loss: 6.9888 - val_mean_squared_error: 6.9888
# Epoch 302/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.1097 - mean_squared_error: 25.1097 - val_loss: 6.9219 - val_mean_squared_error: 6.9219
# Epoch 303/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.7234 - mean_squared_error: 24.7234 - val_loss: 6.8534 - val_mean_squared_error: 6.8534
# Epoch 304/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.4268 - mean_squared_error: 25.4268 - val_loss: 6.7864 - val_mean_squared_error: 6.7864
# Epoch 305/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 26.2868 - mean_squared_error: 26.2868 - val_loss: 6.7221 - val_mean_squared_error: 6.7221
# Epoch 306/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.6165 - mean_squared_error: 27.6165 - val_loss: 6.6537 - val_mean_squared_error: 6.6537
# Epoch 307/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 22.6741 - mean_squared_error: 22.6741 - val_loss: 6.5866 - val_mean_squared_error: 6.5866
# Epoch 308/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.3175 - mean_squared_error: 25.3175 - val_loss: 6.5271 - val_mean_squared_error: 6.5271
# Epoch 309/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.7887 - mean_squared_error: 20.7887 - val_loss: 6.4703 - val_mean_squared_error: 6.4703
# Epoch 310/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.8190 - mean_squared_error: 21.8190 - val_loss: 6.4129 - val_mean_squared_error: 6.4129
# Epoch 311/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.9343 - mean_squared_error: 27.9343 - val_loss: 6.3565 - val_mean_squared_error: 6.3565
# Epoch 312/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.5167 - mean_squared_error: 27.5167 - val_loss: 6.3034 - val_mean_squared_error: 6.3034
# Epoch 313/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.3154 - mean_squared_error: 22.3154 - val_loss: 6.2529 - val_mean_squared_error: 6.2529
# ...
# Epoch 459/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.3677 - mean_squared_error: 21.3677 - val_loss: 3.0582 - val_mean_squared_error: 3.0582
# Epoch 460/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.8337 - mean_squared_error: 20.8337 - val_loss: 3.0520 - val_mean_squared_error: 3.0520
# Epoch 461/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.6650 - mean_squared_error: 20.6650 - val_loss: 3.0467 - val_mean_squared_error: 3.0467
# Epoch 462/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.8467 - mean_squared_error: 19.8467 - val_loss: 3.0410 - val_mean_squared_error: 3.0410
# Epoch 463/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.1795 - mean_squared_error: 18.1795 - val_loss: 3.0375 - val_mean_squared_error: 3.0375
# Epoch 464/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.8711 - mean_squared_error: 20.8711 - val_loss: 3.0334 - val_mean_squared_error: 3.0334
# Epoch 465/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.5344 - mean_squared_error: 21.5344 - val_loss: 3.0295 - val_mean_squared_error: 3.0295
# Epoch 466/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.0689 - mean_squared_error: 23.0689 - val_loss: 3.0252 - val_mean_squared_error: 3.0252
# Epoch 467/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 21.4545 - mean_squared_error: 21.4545 - val_loss: 3.0215 - val_mean_squared_error: 3.0215
# Epoch 468/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.8826 - mean_squared_error: 15.8826 - val_loss: 3.0193 - val_mean_squared_error: 3.0193
# Epoch 469/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.9636 - mean_squared_error: 23.9636 - val_loss: 3.0170 - val_mean_squared_error: 3.0170
# Epoch 470/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.4115 - mean_squared_error: 24.4115 - val_loss: 3.0153 - val_mean_squared_error: 3.0153
# Epoch 471/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.6213 - mean_squared_error: 24.6213 - val_loss: 3.0141 - val_mean_squared_error: 3.0141
# Epoch 472/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.9966 - mean_squared_error: 23.9966 - val_loss: 3.0131 - val_mean_squared_error: 3.0131
# Epoch 473/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.5361 - mean_squared_error: 28.5361 - val_loss: 3.0125 - val_mean_squared_error: 3.0125
# Epoch 474/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.9690 - mean_squared_error: 20.9690 - val_loss: 3.0091 - val_mean_squared_error: 3.0091
# Epoch 475/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.9776 - mean_squared_error: 19.9776 - val_loss: 3.0052 - val_mean_squared_error: 3.0052
# Epoch 476/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.8739 - mean_squared_error: 17.8739 - val_loss: 3.0010 - val_mean_squared_error: 3.0010
# Epoch 477/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.0202 - mean_squared_error: 23.0202 - val_loss: 2.9959 - val_mean_squared_error: 2.9959
# Epoch 478/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.1945 - mean_squared_error: 21.1945 - val_loss: 2.9911 - val_mean_squared_error: 2.9911
# Epoch 479/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.6045 - mean_squared_error: 19.6045 - val_loss: 2.9885 - val_mean_squared_error: 2.9885
# Epoch 480/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.2054 - mean_squared_error: 19.2054 - val_loss: 2.9857 - val_mean_squared_error: 2.9857
# Epoch 481/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.9218 - mean_squared_error: 20.9218 - val_loss: 2.9838 - val_mean_squared_error: 2.9838
# Epoch 482/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.7614 - mean_squared_error: 23.7614 - val_loss: 2.9810 - val_mean_squared_error: 2.9810
# Epoch 483/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.6355 - mean_squared_error: 16.6355 - val_loss: 2.9771 - val_mean_squared_error: 2.9771
# Epoch 484/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 17.3835 - mean_squared_error: 17.3835 - val_loss: 2.9730 - val_mean_squared_error: 2.9730
# Epoch 485/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.3142 - mean_squared_error: 20.3142 - val_loss: 2.9682 - val_mean_squared_error: 2.9682
# Epoch 486/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.2715 - mean_squared_error: 23.2715 - val_loss: 2.9639 - val_mean_squared_error: 2.9639
# Epoch 487/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.3795 - mean_squared_error: 26.3795 - val_loss: 2.9587 - val_mean_squared_error: 2.9587
# Epoch 488/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.7362 - mean_squared_error: 24.7362 - val_loss: 2.9536 - val_mean_squared_error: 2.9536
# Epoch 489/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.0013 - mean_squared_error: 23.0013 - val_loss: 2.9494 - val_mean_squared_error: 2.9494
# Epoch 490/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.4497 - mean_squared_error: 17.4497 - val_loss: 2.9459 - val_mean_squared_error: 2.9459
# Epoch 491/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.4886 - mean_squared_error: 22.4886 - val_loss: 2.9434 - val_mean_squared_error: 2.9434
# Epoch 492/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.1069 - mean_squared_error: 22.1069 - val_loss: 2.9394 - val_mean_squared_error: 2.9394
# Epoch 493/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.0469 - mean_squared_error: 19.0469 - val_loss: 2.9340 - val_mean_squared_error: 2.9340
# Epoch 494/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.5773 - mean_squared_error: 17.5773 - val_loss: 2.9293 - val_mean_squared_error: 2.9293
# Epoch 495/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.3101 - mean_squared_error: 16.3101 - val_loss: 2.9250 - val_mean_squared_error: 2.9250
# Epoch 496/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 26.0395 - mean_squared_error: 26.0395 - val_loss: 2.9218 - val_mean_squared_error: 2.9218
# Epoch 497/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.7580 - mean_squared_error: 24.7580 - val_loss: 2.9196 - val_mean_squared_error: 2.9196
# Epoch 498/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.1185 - mean_squared_error: 22.1185 - val_loss: 2.9172 - val_mean_squared_error: 2.9172
# Epoch 499/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.0587 - mean_squared_error: 21.0587 - val_loss: 2.9141 - val_mean_squared_error: 2.9141
# Epoch 500/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 18.9468 - mean_squared_error: 18.9468 - val_loss: 2.9098 - val_mean_squared_error: 2.9098
# Epoch 501/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.7640 - mean_squared_error: 21.7640 - val_loss: 2.9065 - val_mean_squared_error: 2.9065
# Epoch 502/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.2897 - mean_squared_error: 23.2897 - val_loss: 2.9037 - val_mean_squared_error: 2.9037
# Epoch 503/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.6586 - mean_squared_error: 19.6586 - val_loss: 2.9015 - val_mean_squared_error: 2.9015
# Epoch 504/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.1220 - mean_squared_error: 23.1220 - val_loss: 2.8993 - val_mean_squared_error: 2.8993
# Epoch 505/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 20.6184 - mean_squared_error: 20.6184 - val_loss: 2.8975 - val_mean_squared_error: 2.8975
# Epoch 506/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.6748 - mean_squared_error: 16.6748 - val_loss: 2.8955 - val_mean_squared_error: 2.8955
# Epoch 507/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 16.3807 - mean_squared_error: 16.3807 - val_loss: 2.8933 - val_mean_squared_error: 2.8933
# Epoch 508/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.2108 - mean_squared_error: 24.2108 - val_loss: 2.8909 - val_mean_squared_error: 2.8909
# Epoch 509/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.3134 - mean_squared_error: 24.3134 - val_loss: 2.8883 - val_mean_squared_error: 2.8883
# Epoch 510/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.1825 - mean_squared_error: 25.1825 - val_loss: 2.8858 - val_mean_squared_error: 2.8858
# Epoch 511/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.5553 - mean_squared_error: 24.5553 - val_loss: 2.8827 - val_mean_squared_error: 2.8827
# Epoch 512/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.5157 - mean_squared_error: 26.5157 - val_loss: 2.8799 - val_mean_squared_error: 2.8799
# Epoch 513/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.4605 - mean_squared_error: 22.4605 - val_loss: 2.8789 - val_mean_squared_error: 2.8789
# Epoch 514/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.4840 - mean_squared_error: 23.4840 - val_loss: 2.8777 - val_mean_squared_error: 2.8777
# Epoch 515/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.4675 - mean_squared_error: 21.4675 - val_loss: 2.8767 - val_mean_squared_error: 2.8767
# Epoch 516/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.1448 - mean_squared_error: 18.1448 - val_loss: 2.8754 - val_mean_squared_error: 2.8754
# Epoch 517/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 23.6691 - mean_squared_error: 23.6691 - val_loss: 2.8742 - val_mean_squared_error: 2.8742
# Epoch 518/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.7917 - mean_squared_error: 18.7917 - val_loss: 2.8731 - val_mean_squared_error: 2.8731
# Epoch 519/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.3944 - mean_squared_error: 14.3944 - val_loss: 2.8722 - val_mean_squared_error: 2.8722
# Epoch 520/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.8099 - mean_squared_error: 13.8099 - val_loss: 2.8722 - val_mean_squared_error: 2.8722
# Epoch 521/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.1551 - mean_squared_error: 19.1551 - val_loss: 2.8725 - val_mean_squared_error: 2.8725
# Epoch 522/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.0451 - mean_squared_error: 16.0451 - val_loss: 2.8724 - val_mean_squared_error: 2.8724
# Epoch 523/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.3812 - mean_squared_error: 23.3812 - val_loss: 2.8720 - val_mean_squared_error: 2.8720
# Epoch 524/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.5734 - mean_squared_error: 24.5734 - val_loss: 2.8733 - val_mean_squared_error: 2.8733
# Epoch 525/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.5886 - mean_squared_error: 21.5886 - val_loss: 2.8744 - val_mean_squared_error: 2.8744
# Epoch 526/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.8154 - mean_squared_error: 21.8154 - val_loss: 2.8748 - val_mean_squared_error: 2.8748
# Epoch 527/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 22.6498 - mean_squared_error: 22.6498 - val_loss: 2.8752 - val_mean_squared_error: 2.8752
# Epoch 528/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.7108 - mean_squared_error: 16.7108 - val_loss: 2.8747 - val_mean_squared_error: 2.8747
# Epoch 529/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.7575 - mean_squared_error: 17.7575 - val_loss: 2.8756 - val_mean_squared_error: 2.8756
# Epoch 530/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.2648 - mean_squared_error: 22.2648 - val_loss: 2.8750 - val_mean_squared_error: 2.8750
# Epoch 531/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.5035 - mean_squared_error: 21.5035 - val_loss: 2.8737 - val_mean_squared_error: 2.8737
# Epoch 532/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.1384 - mean_squared_error: 23.1384 - val_loss: 2.8721 - val_mean_squared_error: 2.8721
# Epoch 533/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.6319 - mean_squared_error: 17.6319 - val_loss: 2.8705 - val_mean_squared_error: 2.8705
# Epoch 534/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.8609 - mean_squared_error: 20.8609 - val_loss: 2.8688 - val_mean_squared_error: 2.8688
# Epoch 535/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.1893 - mean_squared_error: 23.1893 - val_loss: 2.8669 - val_mean_squared_error: 2.8669
# Epoch 536/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.9977 - mean_squared_error: 23.9977 - val_loss: 2.8655 - val_mean_squared_error: 2.8655
# Epoch 537/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.8969 - mean_squared_error: 24.8969 - val_loss: 2.8643 - val_mean_squared_error: 2.8643
# Epoch 538/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.7617 - mean_squared_error: 22.7617 - val_loss: 2.8632 - val_mean_squared_error: 2.8632
# Epoch 539/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 22.5108 - mean_squared_error: 22.5108 - val_loss: 2.8616 - val_mean_squared_error: 2.8616
# Epoch 540/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.1173 - mean_squared_error: 22.1173 - val_loss: 2.8596 - val_mean_squared_error: 2.8596
# Epoch 541/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 20.1036 - mean_squared_error: 20.1036 - val_loss: 2.8558 - val_mean_squared_error: 2.8558
# Epoch 542/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.2578 - mean_squared_error: 23.2578 - val_loss: 2.8537 - val_mean_squared_error: 2.8537
# Epoch 543/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.9106 - mean_squared_error: 18.9106 - val_loss: 2.8510 - val_mean_squared_error: 2.8510
# Epoch 544/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.6604 - mean_squared_error: 23.6604 - val_loss: 2.8491 - val_mean_squared_error: 2.8491
# Epoch 545/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.5568 - mean_squared_error: 20.5568 - val_loss: 2.8484 - val_mean_squared_error: 2.8484
# Epoch 546/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 29.4079 - mean_squared_error: 29.4079 - val_loss: 2.8469 - val_mean_squared_error: 2.8469
# Epoch 547/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.2540 - mean_squared_error: 19.2540 - val_loss: 2.8450 - val_mean_squared_error: 2.8450
# Epoch 548/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.1907 - mean_squared_error: 20.1907 - val_loss: 2.8424 - val_mean_squared_error: 2.8424
# Epoch 549/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.6679 - mean_squared_error: 18.6679 - val_loss: 2.8398 - val_mean_squared_error: 2.8398
# Epoch 550/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.9327 - mean_squared_error: 17.9327 - val_loss: 2.8369 - val_mean_squared_error: 2.8369
# Epoch 551/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 25.9766 - mean_squared_error: 25.9766 - val_loss: 2.8355 - val_mean_squared_error: 2.8355
# Epoch 552/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.1660 - mean_squared_error: 19.1660 - val_loss: 2.8345 - val_mean_squared_error: 2.8345
# Epoch 553/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 25.4244 - mean_squared_error: 25.4244 - val_loss: 2.8336 - val_mean_squared_error: 2.8336
# Epoch 554/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 16.4743 - mean_squared_error: 16.4743 - val_loss: 2.8334 - val_mean_squared_error: 2.8334
# Epoch 555/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.0734 - mean_squared_error: 18.0734 - val_loss: 2.8344 - val_mean_squared_error: 2.8344
# Epoch 556/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.9947 - mean_squared_error: 22.9947 - val_loss: 2.8366 - val_mean_squared_error: 2.8366
# Epoch 557/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.8354 - mean_squared_error: 20.8354 - val_loss: 2.8402 - val_mean_squared_error: 2.8402
# Epoch 558/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.5692 - mean_squared_error: 18.5692 - val_loss: 2.8432 - val_mean_squared_error: 2.8432
# Epoch 559/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.3718 - mean_squared_error: 19.3718 - val_loss: 2.8446 - val_mean_squared_error: 2.8446
# Epoch 560/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.2274 - mean_squared_error: 22.2274 - val_loss: 2.8465 - val_mean_squared_error: 2.8465
# Epoch 561/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.8044 - mean_squared_error: 18.8044 - val_loss: 2.8476 - val_mean_squared_error: 2.8476
# Epoch 562/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 21.6534 - mean_squared_error: 21.6534 - val_loss: 2.8485 - val_mean_squared_error: 2.8485
# Epoch 563/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.9544 - mean_squared_error: 17.9544 - val_loss: 2.8495 - val_mean_squared_error: 2.8495
# Epoch 564/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.3228 - mean_squared_error: 20.3228 - val_loss: 2.8498 - val_mean_squared_error: 2.8498

# %% [markdown]
# ### Make 2 Predictions
#
# Generate predictions on the test dataset.
#
# ### Instructions:
# - Use the trained model to make predictions on the test data.
# - Store the predictions for further analysis.

# %%
y_pred = model_rnn.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step

# %% [markdown]
# ### Model 2 Evaluation
#
# Evaluate the performance of your second model on the test dataset.
#
# **Instructions:**
# - Calculate evaluation metrics such as MAE, MSE, RMSE, or MAPE.
# - Plot the predicted vs actual values for the test set.
# - Plot the loss and the validation loss.

# %%
pd.DataFrame(y_pred).plot()
pd.DataFrame(y_test).plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse


print(mean_squared_error(y_pred,y_test))
print(rmse(y_pred,y_test))
# Out:
# 1.1908309945005673
# [0.03683613 1.02224994 1.24583058 0.19095962 0.31968555 0.58050275
#  0.9571049  1.01316942 1.47129845 1.70452426 1.39624085 0.97183609
#  0.57150275 0.48129845 0.51616942 1.29678232 1.59904039 1.87216942
#  2.22162103 1.81483609 1.24420168 0.7671049  0.40827287 0.05552659
#  0.20068667 0.0658146  0.15620391]

# %% [markdown]
# ## Conclusion and Interpretation
#
# Write your conclusions based on the model's performance and the forecast.
#
# **Instructions:**
# - Interpret the results and discuss the effectiveness of your model.
# - Suggest potential improvements.
