# %% [markdown]
# ## read the data

# %%
import pandas as pd

# %%
# path = "/content/archive.zip"

# %%
# #!unzip $path # CLI
# !unzip  "/content/archive.zip"

# %%
df = pd.read_csv('/content/training.1600000.processed.noemoticon.csv', encoding='latin-1', names=['target', 'id', 'time', 'flag', 'user', 'text'])
df.head()
# Out:
#    target          id                          time      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %% [markdown]
# ## Explore the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   id      1600000 non-null  int64
#  2   time    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df
# Out:
#          target          id                          time      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
df.sample(10)
# Out:
#          target          id                          time      flag  \
# 443781        0  2067647037  Sun Jun 07 12:42:46 PDT 2009  NO_QUERY
# 146701        0  1882555623  Fri May 22 07:04:59 PDT 2009  NO_QUERY
# 482896        0  2180168882  Mon Jun 15 10:06:10 PDT 2009  NO_QUERY
# 964754        4  1827548560  Sun May 17 10:56:49 PDT 2009  NO_QUERY
# 603050        0  2221556856  Thu Jun 18 05:36:14 PDT 2009  NO_QUERY
# 1089113       4  1969669803  Sat May 30 00:48:32 PDT 2009  NO_QUERY
# 537321        0  2198724662  Tue Jun 16 16:28:55 PDT 2009  NO_QUERY
# 753407        0  2286874526  Mon Jun 22 17:02:40 PDT 2009  NO_QUERY
# 1190503       4  1983726537  Sun May 31 13:42:57 PDT 2009  NO_QUERY
# 793776        0  2326745646  Thu Jun 25 07:27:21 PDT 2009  NO_QUERY
#
#                     user                                               text
# 443781       kieranlemon  history exams suck  i suck at revising for his...
# ...

# %%
df.head(10)
# Out:
#    target          id                          time      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5       0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6       0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7       0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 8       0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 9       0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# ...

# %%
df['flag'].unique()
# Out:
# array(['NO_QUERY'], dtype=object)

# %%
df['time']
# Out:
# 0          Mon Apr 06 22:19:45 PDT 2009
# 1          Mon Apr 06 22:19:49 PDT 2009
# 2          Mon Apr 06 22:19:53 PDT 2009
# 3          Mon Apr 06 22:19:57 PDT 2009
# 4          Mon Apr 06 22:19:57 PDT 2009
#                        ...
# 1599995    Tue Jun 16 08:40:49 PDT 2009
# 1599996    Tue Jun 16 08:40:49 PDT 2009
# 1599997    Tue Jun 16 08:40:49 PDT 2009
# 1599998    Tue Jun 16 08:40:49 PDT 2009
# 1599999    Tue Jun 16 08:40:50 PDT 2009
# Name: time, Length: 1600000, dtype: object

# %%
df['text'].value_counts()
# Out:
# text
# isPlayer Has Died! Sorry                                                                              210
# good morning                                                                                          118
# headache                                                                                              115
# Good morning                                                                                          112
# Headache                                                                                              106
#                                                                                                      ...
# braces  tell me it will be okay...                                                                      1
# is stuck at home without curry                                                                          1
# @mrsduryee I've applied to about 70 since I lost my job in March...it certainly FEELS like a lot!       1
# ...

# %%
df.target.value_counts()
# Out:
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
df['time'] = pd.to_datetime(df['time'])
# Out:
# <ipython-input-50-c9b798e2217d>:1: FutureWarning: Parsed string "Mon Apr 06 22:19:45 PDT 2009" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df['time'] = pd.to_datetime(df['time'])

# %%
df.time.dt.hour.value_counts()
# Out:
# time
# 23    84750
# 7     83654
# 0     80865
# 6     80852
# 5     78623
# 22    78328
# 4     76995
# 8     76287
# 1     75268
# 3     74253
# 2     73991
# 21    68964
# 9     67278
# 11    61009
# 10    60689
# 19    57722
# 20    57059
# 16    55720
# 18    53485
# 17    51843
# 12    51653
# 15    50643
# 14    50380
# 13    49689
# Name: count, dtype: int64

# %%
df['time'].sort_values()
# Out:
# 0        2009-04-06 22:19:45
# 1        2009-04-06 22:19:49
# 2        2009-04-06 22:19:53
# 3        2009-04-06 22:19:57
# 4        2009-04-06 22:19:57
#                  ...
# 799995   2009-06-25 10:28:28
# 799996   2009-06-25 10:28:28
# 799997   2009-06-25 10:28:30
# 799998   2009-06-25 10:28:30
# 799999   2009-06-25 10:28:31
# Name: time, Length: 1600000, dtype: datetime64[ns]

# %%
df.time.dt.hour.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='time'>

# %%
df.time.dt.day.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='time'>

# %%
# data basicaly collected on june as a start
df.time.dt.month.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='time'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='target', data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
df.drop(columns=['id','time','flag', 'user'], inplace=True)

# %% [markdown]
# ## Splitting Data

# %%
small_df = df[:100000]
small_df.target.value_counts()
# Out:
# target
# 0    100000
# Name: count, dtype: int64

# %%
small_df = df.sample(100000, random_state=42)
small_df.target.value_counts()
# Out:
# target
# 4    50057
# 0    49943
# Name: count, dtype: int64

# %%
df['target'] = df['target'].replace({4:1})

# %%
small_df = df.sample(100000, random_state=42)
small_df.target.value_counts()
# Out:
# target
# 1    50057
# 0    49943
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(df, test_size=0.3, random_state=42)    # recommend it test size = 0.05
train, val = train_test_split(train_val, test_size=0.3, random_state=42)

# %% [markdown]
# ##EDA >> only in training
#
# - Length of tweets
# - The most common words on twitter
# - The most common words on targer (pos vs Neg)
# - Upper CASE words
# - Analyse Hashtages -> (if you are interested to something related to hashtage not analyse tweets)

# %%
df.duplicated().sum()
# Out:
# 16309

# %%
df.drop_duplicates(inplace=True)

# %%
train
# Out:
#          target                                               text
# 1131245       1  @miss_english: had an awesome time today, we h...
# 1588559       1  wishes everyone the best health so that the vi...
# 1137998       1        We were never meant to be we just happened
# 1039495       1  Plant pot shop still in progress in Willawong....
# 495049        0                        is over open house already
# ...         ...                                                ...
# 170515        0                              @temple3000 starbuck
# 594435        0                   Power just went out at my house
# 6777          0  @RyanSeacrest apparently your site is unable t...
# 1393084       1  @wlvs The lack of engines is made up for by th...
# 1029790       1  @krritchie I really enjoyed dialogue tonight. ...
#
# [784000 rows x 2 columns]

# %%
train.columns
# Out:
# Index(['target', 'text'], dtype='object')

# %% [markdown]
# ##Length of tweets

# %%
# len(train['text']) # len

# %%
train['Length'] = train['text'].str.len()
train['Length'] # we will drop it latter this is just for analyses
# Out:
# 1131245     67
# 1588559    101
# 1137998     43
# 1039495    131
# 495049      27
#           ...
# 170515      21
# 594435      32
# 6777        86
# 1393084     74
# 1029790    106
# Name: Length, Length: 784000, dtype: int64

# %%
train['Length'].describe()
# Out:
# count    784000.000000
# mean         74.088129
# std          36.443471
# min           6.000000
# 25%          44.000000
# 50%          69.000000
# 75%         104.000000
# max         374.000000
# Name: Length, dtype: float64

# %%
train.Length.describe()
# Out:
# count    784000.000000
# mean         74.088129
# std          36.443471
# min           6.000000
# 25%          44.000000
# 50%          69.000000
# 75%         104.000000
# max         374.000000
# Name: Length, dtype: float64

# %%
train['Length'].plot(kind='box')
# Out:
# <Axes: >

# %%
train['Length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train[train['Length'] < 10]
# Out:
#          target       text  Length
# 1132614       1   careers        8
# 297979        0  Angustia        9
# 340171        0   doctors        8
# 188939        0  So tired        9
# 633330        0   @therev        8
# ...         ...        ...     ...
# 1417111       1  Were 4/4        9
# 1184694       1  Hey hey!        9
# 734560        0  @rushist        9
# 862709        1  I saw it        9
# 627060        0  grounded        9
#
# [1558 rows x 3 columns]

# %%
sns.boxplot(y ='Length', hue='target', data=train);

# %% [markdown]
# what is the maximum number of tweets of chars on twitter?

# %%
train[train['Length'] > 140]
# Out:
#          target                                               text  Length
# 574522        0  With the Jim Hugunin keynote withdrawn  PSF Ch...     141
# 50386         0  @ellendecoo Heard about Beck's you're either w...     141
# 988546        1  Yes,Hitler believed that Germans are decendant...     147
# 1281658       1  @jspriddleuk @Mamalonglegs  Pants - found out!...     148
# 793652        0  @ Leah_Sullivan School is finally over i am mi...     142
# ...         ...                                                ...     ...
# 467090        0  &quot;Smulan&quot; sank  and I ended up on a o...     144
# 235262        0  Oh &amp; I luv U Starbucks Iced Coffee with a ...     142
# 159168        0  @Hanadi7994 @Hanadi7994 ahh yeah idk how i'm g...     148
# 1476548       1  Getting some breakfast burritos w/M&amp;D  the...     146
# 396645        0  We made it through!! Unfortunately she's havin...     141
#
# [8404 rows x 3 columns]

# %% [markdown]
# Hint

# %%
sen = 'hello  world'
len(sen)
# Out:
# 12

# %%
sen = 'مُعسكر'
len(sen)
# Out:
# 6

# %%
sen = 'معسكــــر'
len(sen)
# Out:
# 9

# %%
# !pip install pyarabic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 7.9 MB/s eta 0:00:00
# ...

# %%
from pyarabic.araby import strip_tashkeel
sen = 'مُعسكر'
len(sen)

strip_tashkeel(sen)
# Out:
# 'معسكر'

# %%
sen = 'معسكــــر'
strip_tashkeel(sen)
# Out:
# 'معسكــــر'

# %% [markdown]
# ##The most common words on twitter

# %%
import nltk
nltk.download('word_tokenize')
# Out:
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index
# False

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
train['text'].str.lower().str.split()
# Out:
# 1131245    [@miss_english:, had, an, awesome, time, today...
# 1588559    [wishes, everyone, the, best, health, so, that...
# 1137998    [we, were, never, meant, to, be, we, just, hap...
# 1039495    [plant, pot, shop, still, in, progress, in, wi...
# 495049                      [is, over, open, house, already]
#                                  ...
# 170515                               [@temple3000, starbuck]
# 594435               [power, just, went, out, at, my, house]
# 6777       [@ryanseacrest, apparently, your, site, is, un...
# 1393084    [@wlvs, the, lack, of, engines, is, made, up, ...
# 1029790    [@krritchie, i, really, enjoyed, dialogue, ton...
# Name: text, Length: 784000, dtype: object

# %%
from nltk.tokenize import word_tokenize

train['text_tokenize'] = train['text'].str.lower().map(word_tokenize)
train['text_tokenize']
# Out:
# 1131245    [@, miss_english, :, had, an, awesome, time, t...
# 1588559    [wishes, everyone, the, best, health, so, that...
# 1137998    [we, were, never, meant, to, be, we, just, hap...
# 1039495    [plant, pot, shop, still, in, progress, in, wi...
# 495049                      [is, over, open, house, already]
#                                  ...
# 170515                             [@, temple3000, starbuck]
# 594435               [power, just, went, out, at, my, house]
# 6777       [@, ryanseacrest, apparently, your, site, is, ...
# 1393084    [@, wlvs, the, lack, of, engines, is, made, up...
# 1029790    [@, krritchie, i, really, enjoyed, dialogue, t...
# Name: text_tokenize, Length: 784000, dtype: object

# %%
from collections import Counter

ls = ['the', 'hours', 'the']
cnt = Counter(ls)
cnt
# Out:
# Counter({'the': 2, 'hours': 1})

# %%
ls2 = ['the', 'hi']
cnt.update(ls2)
cnt
# Out:
# Counter({'the': 3, 'hours': 1, 'hi': 1})

# %%
pd.DataFrame(cnt.most_common(10)).set_index(0).plot(kind='bar', legend=False)
# Out:
# <Axes: xlabel='0'>

# %%
from collections import Counter
cnt = Counter()

train['text_tokenize'].apply(cnt.update)  # lambda x: cnt.update(x)
cnt
# Out:
# Counter({'@': 390815,
#          'miss_english': 1,
#          ':': 63236,
#          'had': 23771,
#          'an': 17126,
#          'awesome': 8784,
#          'time': 28103,
#          'today': 33080,
#          ',': 236945,
#          'we': 30994,
#          'have': 75287,
#          'to': 276946,
#          'continue': 347,
#          'this': 46150,
#          'wishes': 1023,
#          'everyone': 7995,
#          'the': 256117,
#          'best': 7984,
#          'health': 359,
#          'so': 75523,
#          'that': 80972,
#          'virus': 250,
#          'scare': 172,
#          'wo': 5071,
#          "n't": 85598,
#          'get': 40313,
#          'them': 12120,
#          '.': 392088,
#          'http': 35074,
#          '//plurk.com/p/11c3kk': 1,
#          'were': 9187,
#          'never': 8773,
#          'meant': 1161,
#          'be': 55382,
#          'just': 62334,
#          'happened': 1797,
#          'plant': 180,
#          'pot': 240,
# ...

# %%
pd.DataFrame(cnt.most_common(10)).set_index(0).plot(kind='bar', legend=False)
# Out:
# <Axes: xlabel='0'>

# %%
pos_sen = train[train.target == 1]
pos_neg = train[train.target == 0]

# %%
pos_text = pos_sen.text.str.cat(sep=' ') # make all pos tweets as one string for word cloud
pos_text
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
neg_text = pos_neg.text.str.cat(sep=' ')
neg_text
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from collections import Counter

Counter(word_tokenize(pos_text))
# Out:
# Counter({'@': 233208,
#          'miss_english': 1,
#          ':': 38007,
#          'had': 8588,
#          'an': 8336,
#          'awesome': 5607,
#          'time': 13254,
#          'today': 13282,
#          ',': 127033,
#          'we': 12958,
#          'have': 28184,
#          'to': 121567,
#          'continue': 185,
#          'this': 18032,
#          'wishes': 321,
#          'everyone': 4507,
#          'the': 121340,
#          'best': 4704,
#          'health': 140,
#          'so': 27405,
#          'that': 35529,
#          'virus': 50,
#          'scare': 67,
#          'wo': 1068,
#          "n't": 26258,
#          'get': 16230,
#          'them': 5900,
#          '.': 182396,
#          'http': 23024,
#          '//plurk.com/p/11c3kk': 1,
#          'We': 3954,
#          'were': 3832,
#          'never': 2803,
#          'meant': 564,
#          'be': 25881,
#          'just': 23325,
#          'happened': 352,
#          'Plant': 10,
#          'pot': 112,
# ...

# %%
from wordcloud import WordCloud
from matplotlib.pyplot import imshow
# WordCloud?

love_wc = WordCloud().generate('love love love it')
imshow(love_wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from wordcloud import WordCloud
from matplotlib.pyplot import imshow

plt.figure(figsize=(10,10))
love_wc = WordCloud(background_color='black').generate(pos_text)
imshow(love_wc)
plt.axis('off')
plt.title('Positive Tweets')
# Out:
# Text(0.5, 1.0, 'Positive Tweets')

# %%
from wordcloud import WordCloud
from matplotlib.pyplot import imshow

plt.figure(figsize=(10,10))
love_wc = WordCloud(background_color='white').generate(neg_text)
imshow(love_wc)
plt.axis('off')
plt.title('Positive Tweets')
# Out:
# Text(0.5, 1.0, 'Positive Tweets')

# %% [markdown]
# ##Preprocessing
#
# **Garbage in -> Garbage out**
#
# Preprocessing depends on multiple factors:
#
# - **Lang**: English -> lowercase vs Arabic -> strip tashkeel
#
# - **Data Source** -> tweets -> spelling
# correction VS research papers will never appply spelling correction
#
# - **Task**: target (sentiment) analysis -> stop word removal VS translation will never apply stop word removal
#
# Here in sentiment analysis (order does matter):
#
# - Remove extra spaces (strip)
# - Longataion -> "Loooove"
# - Drop long/short tweets
# - Remove non-useful text (handles, links, ..) -> @xxx or www.bla.com
#
#
#
#
# - Lemmatization -> (play, plays, played, playing)
#
# - Lowercase -> Car != car
# - Stop word removal
# - Expand contactions -> "I'm" != "I am"
#
# - Remove puncts -> ?;:@
#
#
# - Stemming (if did't applied lemmatization) -> (play, plays, played, playing)
# - Text normalization -> 4you, for you
# - Remove numbers
# - Spelling correction -> helo
#
#
#
# **Order does matter**
#
# Ex: if you remove puncts `@` you cant remove mentions or handles `@blabla`. You need first to remove handles then remove punctuations

# %% [markdown]
# #remove extra speces

# %%
train['text'] = train['text'].str.strip()

# %% [markdown]
# #All above steps in pipeline

# %%
def preprocess(text):
# Out:
#   File "<ipython-input-100-49ba817d4677>", line 1
#     def preprocess(text):
#                          ^
# SyntaxError: incomplete input

# %%
train['text']

# %%
# !pip install contractions
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 9.1 MB/s eta 0:00:00
# ...

# %%
from contractions import contractions_dict

contractions_dict
# Out:
# {"I'm": 'I am',
#  "I'm'a": 'I am about to',
#  "I'm'o": 'I am going to',
#  "I've": 'I have',
#  "I'll": 'I will',
#  "I'll've": 'I will have',
#  "I'd": 'I would',
#  "I'd've": 'I would have',
#  'Whatcha': 'What are you',
#  "amn't": 'am not',
#  "ain't": 'are not',
#  "aren't": 'are not',
#  "'cause": 'because',
#  "can't": 'cannot',
#  "can't've": 'cannot have',
#  "could've": 'could have',
#  "couldn't": 'could not',
#  "couldn't've": 'could not have',
#  "daren't": 'dare not',
#  "daresn't": 'dare not',
#  "dasn't": 'dare not',
#  "didn't": 'did not',
#  'didn’t': 'did not',
#  "don't": 'do not',
#  'don’t': 'do not',
#  "doesn't": 'does not',
#  "e'er": 'ever',
#  "everyone's": 'everyone is',
#  'finna': 'fixing to',
#  'gimme': 'give me',
#  "gon't": 'go not',
#  'gonna': 'going to',
#  'gotta': 'got to',
#  "hadn't": 'had not',
#  "hadn't've": 'had not have',
#  "hasn't": 'has not',
#  "haven't": 'have not',
#  "he've": 'he have',
#  "he's": 'he is',
#  "he'll": 'he will',
# ...

# %%
tweet = "hey!, what's going on here?, aren't you stuped or what?, what did you say"

expanded_tweet = []
for word in tweet.split():
  if word in contractions_dict:
    expanded_tweet.append(contractions_dict[word])
  else:
    expanded_tweet.append(word)

' '.join(expanded_tweet)
# Out:
# 'hey!, what is going on here?, are not you stuped or what?, what did you say'

# %%
' '.join([contractions_dict[word] if word in contractions_dict else word for word in tweet.split()])
# Out:
# 'hey!, what is going on here?, are not you stuped or what?, what did you say'
